# %% [markdown]
# <a href="https://colab.research.google.com/github/SinoLewis/machine-learning-colabs/blob/main/Copy_of_OpenAI_Whisper_Fed_Meeting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## OpenAI Whisper
#
# To get started, we'll first install the OpenAI Whisper Python package using pip.

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#      |████████████████████████████████| 5.8 MB 12.1 MB/s
#      |████████████████████████████████| 182 kB 14.0 MB/s
#      |████████████████████████████████| 7.6 MB 54.6 MB/s
#   Building wheel for whisper (setup.py) ... done

# %% [markdown]
# We'll also make sure we have a GPU available in Google Colab. If you don't have a GPU, go to Runtime -> Change Runtime Type -> Hardware Accelator and select GPU. I have Colab Pro so I get access to Premium GPU's. Run the command below to show which GPU is being used in the current runtime:

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-e1ee1b27-f2e1-79f5-7f5f-45c24b4752bc)

# %% [markdown]
# Whisper transcribes audio speech to text. To see this in action, we'll need some audio to operate on. We'll extract some audio from a YouTube video using the pytube Python package. let's install it with pip.

# %%
# !pip install pytube -q
# Out:
#      |████████████████████████████████| 56 kB 4.2 MB/s

# %% [markdown]
# Now that we have installed the dependencies, let's import whisper and the YouTube class from pytube.

# %%
import whisper
from pytube import YouTube

# %% [markdown]
# Whisper has a variety of models of varying sizes. The large model will be more accurate but will also be more resource intensive.

# %% [markdown]
# ![Screen Shot 2022-11-18 at 4.27.50 PM.png](data:image/png;base64,...)

# %% [markdown]
# The base model will be sufficient for our needs. Let's load the base model like so:

# %%
model = whisper.load_model('base')
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 120MiB/s]

# %% [markdown]
# We'll now instantiate a "YouTube" object by passing in the video URL. This will allow us to retrieve metadata and stream info about the specified YouTube URL.

# %%
youtube_video_url = "https://www.youtube.com/watch?v=NT2H9iyd-ms"
youtube_video = YouTube(youtube_video_url)

# %% [markdown]
# Now that we have an pytube YouTube object, let's explore some of its attributes.

# %%
youtube_video.title
# Out:
# 'WATCH LIVE | Fed Chair Powell Discusses Latest Fed Rate Hike'

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
youtube_video.streams
# Out:
# [<Stream: itag="17" mime_type="video/3gpp" res="144p" fps="7fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">, <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %% [markdown]
# As you can see, we have a list of video and audio streams of varying quality. We can iterate over this list and observe the different resolutions and framerates.

# %%
for stream in youtube_video.streams:
  print(stream)
# Out:
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="7fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">
# <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %% [markdown]
# For this tutorial, we are interested in the audio channel only. Thus, we will filter down to audio streams only.

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %% [markdown]
# We don't need the highest quality audio for this project, so we'll select the first audio stream available. If we want a higher quality transcription, we can select a higher quality audio stream and use a larger Whisper model.

# %%
stream = streams.first()
stream
# Out:
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">

# %% [markdown]
# Now that we have selected stream we are working with, let's download the stream as fed_meeting.mp4. You should see the file appear in the filesystem browser on the side panel of Colab. Click the refresh button if you don't see it after a while.

# %%
stream.download(filename='fed_meeting.mp4')
# Out:
# '/content/fed_meeting.mp4'

# %% [markdown]
# We can do some additional processing on the audio file should we choose. I want to ignore any additional sound and speech after Jerome Powell speaks. So we'll use ffmpeg to do this. The command will start the audio file at the 375 second mark where he starts with good afternoon, continue for 2715 seconds, and chop off the rest of the audio. The result will be saved in a new file called fed_meeting_trimmed.mp4.

# %%
# !ffmpeg -ss 378 -i fed_meeting.mp4 -t 2715 fed_meeting_trimmed.mp4
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'fed_meeting.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2022-11-05T10:36:04.000000Z
#   Duration: 01:00:53.85, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-05T10:36:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'fed_meeting_trimmed.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-05T10:36:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc57.107.100 aac
# size=   43204kB time=00:45:15.01 bitrate= 130.4kbits/s speed=20.2x
# video:0kB audio:42746kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.071794%
# [aac @ 0x560276991900] Qavg: 654.901

# %% [markdown]
# It is possible to embed an audio player into Google Colab, but will not do this for now since I have seen the runtime get disconnected on large audio files. If you want a copy of the resulting audio, you can download it locally using the Colab the file browser.

# %%
import datetime

# save a timestamp before transcription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("fed_meeting_trimmed.mp4")

# show time elapsed after transcription is complete.
t2 = datetime.datetime.now()
print(f"ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2022-12-16 02:27:27.872579
# ended at 2022-12-16 02:29:25.640375
# time elapsed: 0:01:57.767796

# %% [markdown]
# How long with CPU? Switch to GPU on Colab Free. How long? 2:24. Compare to Colab Pro. 1:45. Compare to Macbook Pro M1.

# %%
output
# Out:
# {'text': " Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal. We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses. Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy. Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all. Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate. We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%. In addition, we are continuing the process of significantly reducing the size of our balance sheet. Restoring price stability will likely require maintaining a restrictive stance of policy for some time. I will have more to say about today's monetary policy actions after briefly reviewing economic developments. The U.S. economy has slowed significantly from last year's rapid pace. Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year. Recent indicators point to modest growth of spending and production this quarter. Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions. Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates. Higher interest rates and slower output growth also appear to be weighing on business fixed investment. Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low. Job vacancies still very high and wage growth elevated. Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September. Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers. The labor force participation rate is little changed since the beginning of the year. Inflation remains well above our longer run goal of 2%. Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%. The recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services. Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation. Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters, as well as measures from financial markets. That is not grounds for complacency. The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched. The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people. My colleagues and I are acutely aware that high inflation imposes significant hardship and is at erode's purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation. We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective. At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points, and we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in firming the stance of monetary ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 8.0,
#    'text': ' Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal.',
#    'tokens': [2205,
#     6499,
#     13,
#     1222,
#     7734,
#     293,
#     286,
#     366,
#     10613,
#     7784,
#     281,
#     5062,
#     15860,
#     646,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14512778617240288,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247036159038544},
#   {'id': 1,
#    'seek': 0,
#    'start': 8.0,
#    'end': 16.0,
#    'text': ' We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses.',
#    'tokens': [492,
#     362,
#     1293,
#     264,
#     3873,
#     300,
#     321,
#     643,
#     293,
#     264,
#     14151,
#     309,
#     486,
#     747,
#     281,
#     15227,
#     3218,
#     11826,
#     322,
#     9490,
#     295,
#     2665,
#     4466,
#     293,
#     6011,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14512778617240288,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247036159038544},
#   {'id': 2,
#    'seek': 0,
#    'start': 16.0,
#    'end': 22.0,
#    'text': ' Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy.',
#    'tokens': [25803,
#     11826,
#     307,
#     264,
#     6357,
#     295,
#     264,
#     12380,
#     26049,
#     293,
#     13451,
#     382,
#     264,
#     2901,
#     17799,
#     295,
#     527,
#     5010,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14512778617240288,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247036159038544},
#   {'id': 3,
#    'seek': 2200,
#    'start': 22.0,
#    'end': 34.0,
#    'text': ' Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all.',
#    'tokens': [9129,
#     3218,
#     11826,
#     11,
#     264,
#     5010,
#     775,
#     406,
#     589,
#     337,
#     2878,
#     13,
#     682,
#     1729,
#     11,
#     1553,
#     3218,
#     11826,
#     11,
#     321,
#     486,
#     406,
#     4584,
#     257,
#     23389,
#     2896,
#     295,
#     2068,
#     5938,
#     2142,
#     4487,
#     300,
#     5121,
#     439,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06894857743207146,
#    'compression_ratio': 1.5251141552511416,
#    'no_speech_prob': 0.0018597592134028673},
#   {'id': 4,
#    'seek': 2200,
#    'start': 34.0,
#    'end': 45.0,
#    'text': ' Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate.',
#    'tokens': [2692,
#     11,
#     264,
#     479,
#     5251,
#     34,
#     6005,
#     527,
#     3897,
#     1179,
#     3314,
#     538,
#     9562,
#     5143,
#     2793,
#     293,
#     321,
#     2354,
#     281,
#     21685,
#     300,
#     10452,
#     8637,
#     486,
#     312,
#     6854,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06894857743207146,
#    'compression_ratio': 1.5251141552511416,
#    'no_speech_prob': 0.0018597592134028673},
#   {'id': 5,
#    'seek': 4500,
#    'start': 45.0,
#    'end': 52.0,
#    'text': ' We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%.',
#    'tokens': [492,
#     366,
#     2684,
#     527,
#     3897,
#     21033,
#     4334,
#     2277,
#     281,
#     257,
#     1496,
#     300,
#     486,
#     312,
#     31868,
#     43220,
#     281,
#     2736,
#     15860,
#     281,
#     568,
#     6856],
#    'temperature': 0.0,
#    'avg_logprob': -0.03869106629315545,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.0007517836056649685},
#   {'id': 6,
#    'seek': 4500,
#    'start': 52.0,
#    'end': 58.0,
#    'text': ' In addition, we are continuing the process of significantly reducing the size of our balance sheet.',
#    'tokens': [682,
#     4500,
#     11,
#     321,
#     366,
#     9289,
#     264,
#     1399,
#     295,
#     10591,
#     12245,
#     264,
#     2744,
#     295,
#     527,
#     4772,
#     8193,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.03869106629315545,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.0007517836056649685},
#   {'id': 7,
#    'seek': 4500,
#    'start': 58.0,
#    'end': 65.0,
#    'text': ' Restoring price stability will likely require maintaining a restrictive stance of policy for some time.',
#    'tokens': [13094,
#     3662,
#     3218,
#     11826,
#     486,
#     3700,
#     3651,
#     14916,
#     257,
#     43220,
#     21033,
#     295,
#     3897,
#     337,
#     512,
#     565,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.03869106629315545,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.0007517836056649685},
#   {'id': 8,
#    'seek': 4500,
#    'start': 65.0,
#    'end': 73.0,
#    'text': " I will have more to say about today's monetary policy actions after briefly reviewing economic developments.",
#    'tokens': [286,
#     486,
#     362,
#     544,
#     281,
#     584,
#     466,
#     965,
#     311,
#     26388,
#     3897,
#     5909,
#     934,
#     10515,
#     19576,
#     4836,
#     20862,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.03869106629315545,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.0007517836056649685},
#   {'id': 9,
#    'seek': 7300,
#    'start': 73.0,
#    'end': 79.0,
#    'text': " The U.S. economy has slowed significantly from last year's rapid pace.",
#    'tokens': [440,
#     624,
#     13,
#     50,
#     13,
#     5010,
#     575,
#     32057,
#     10591,
#     490,
#     1036,
#     1064,
#     311,
#     7558,
#     11638,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06411807310013544,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.0005245014326646924},
#   {'id': 10,
#    'seek': 7300,
#    'start': 79.0,
#    'end': 86.0,
#    'text': ' Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year.',
#    'tokens': [8467,
#     19599,
#     10895,
#     412,
#     257,
#     11638,
#     295,
#     568,
#     13,
#     21,
#     4,
#     1036,
#     6555,
#     457,
#     307,
#     44553,
#     370,
#     1400,
#     341,
#     1064,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06411807310013544,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.0005245014326646924},
#   {'id': 11,
#    'seek': 7300,
#    'start': 86.0,
#    'end': 91.0,
#    'text': ' Recent indicators point to modest growth of spending and production this quarter.',
#    'tokens': [17553,
#     22176,
#     935,
#     281,
#     25403,
#     4599,
#     295,
#     6434,
#     293,
#     4265,
#     341,
#     6555,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06411807310013544,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.0005245014326646924},
#   {'id': 12,
#    'seek': 7300,
#    'start': 91.0,
#    'end': 100.0,
#    'text': " Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions.",
#    'tokens': [48345,
#     294,
#     9711,
#     6434,
#     575,
#     32057,
#     490,
#     1036,
#     1064,
#     311,
#     7558,
#     11638,
#     294,
#     644,
#     23543,
#     3126,
#     957,
#     41578,
#     5742,
#     293,
#     30443,
#     4669,
#     4487,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06411807310013544,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.0005245014326646924},
#   {'id': 13,
#    'seek': 10000,
#    'start': 100.0,
#    'end': 106.0,
#    'text': ' Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates.',
#    'tokens': [3251,
#     4253,
#     294,
#     264,
#     6849,
#     6977,
#     575,
#     42613,
#     10591,
#     11,
#     11611,
#     23543,
#     2946,
#     20236,
#     6846,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09521892131903233,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.00042902666609734297},
#   {'id': 14,
#    'seek': 10000,
#    'start': 106.0,
#    'end': 113.0,
#    'text': ' Higher interest rates and slower output growth also appear to be weighing on business fixed investment.',
#    'tokens': [31997,
#     1179,
#     6846,
#     293,
#     14009,
#     5598,
#     4599,
#     611,
#     4204,
#     281,
#     312,
#     31986,
#     322,
#     1606,
#     6806,
#     6078,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09521892131903233,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.00042902666609734297},
#   {'id': 15,
#    'seek': 10000,
#    'start': 113.0,
#    'end': 119.0,
#    'text': ' Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low.',
#    'tokens': [11334,
#     264,
#     2964,
#     5093,
#     294,
#     4599,
#     11,
#     264,
#     5938,
#     2142,
#     7023,
#     4664,
#     4524,
#     365,
#     264,
#     17438,
#     3314,
#     412,
#     257,
#     2625,
#     12,
#     5294,
#     2295,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09521892131903233,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.00042902666609734297},
#   {'id': 16,
#    'seek': 10000,
#    'start': 119.0,
#    'end': 124.0,
#    'text': ' Job vacancies still very high and wage growth elevated.',
#    'tokens': [18602, 2842, 32286, 920, 588, 1090, 293, 15444, 4599, 23457, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09521892131903233,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.00042902666609734297},
#   {'id': 17,
#    'seek': 12400,
#    'start': 124.0,
#    'end': 133.0,
#    'text': ' Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September.',
#    'tokens': [18602,
#     16823,
#     362,
#     668,
#     13956,
#     365,
#     11949,
#     11636,
#     538,
#     364,
#     4274,
#     295,
#     7562,
#     24,
#     11,
#     1360,
#     4782,
#     680,
#     1618,
#     670,
#     6897,
#     293,
#     7216,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.056701350856471704,
#    'compression_ratio': 1.5108225108225108,
#    'no_speech_prob': 0.00013722371659241617},
#   {'id': 18,
#    'seek': 12400,
#    'start': 133.0,
#    'end': 148.0,
#    'text': ' Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers.',
#    'tokens': [5780,
#     1691,
#     2842,
#     32286,
#     362,
#     4259,
#     2507,
#     641,
#     29687,
#     293,
#     264,
#     11638,
#     295,
#     1691,
#     16823,
#     575,
#     32057,
#     490,
#     3071,
#     294,
#     264,
#     1064,
#     11,
#     264,
#     5938,
#     2142,
#     6515,
#     281,
#     312,
#     484,
#     295,
#     4772,
#     11,
#     365,
#     4733,
#     30797,
#     14048,
#     278,
#     264,
#     5847,
#     295,
#     2435,
#     5600,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.056701350856471704,
#    'compression_ratio': 1.5108225108225108,
#    'no_speech_prob': 0.00013722371659241617},
#   {'id': 19,
#    'seek': 14800,
#    'start': 148.0,
#    'end': 154.0,
#    'text': ' The labor force participation rate is little changed since the beginning of the year.',
#    'tokens': [440,
#     5938,
#     3464,
#     13487,
#     3314,
#     307,
#     707,
#     3105,
#     1670,
#     264,
#     2863,
#     295,
#     264,
#     1064,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11466116375393337,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.00017902861873153597},
#   {'id': 20,
#    'seek': 14800,
#    'start': 154.0,
#    'end': 158.0,
#    'text': ' Inflation remains well above our longer run goal of 2%.',
#    'tokens': [682,
#     3423,
#     399,
#     7023,
#     731,
#     3673,
#     527,
#     2854,
#     1190,
#     3387,
#     295,
#     568,
#     6856],
#    'temperature': 0.0,
#    'avg_logprob': -0.11466116375393337,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.00017902861873153597},
#   {'id': 21,
#    'seek': 14800,
#    'start': 158.0,
#    'end': 170.0,
#    'text': ' Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%.',
#    'tokens': [4886,
#     264,
#     2272,
#     2493,
#     8121,
#     294,
#     7216,
#     11,
#     3217,
#     6465,
#     36,
#     7901,
#     10895,
#     412,
#     1386,
#     13,
#     17,
#     8923,
#     49999,
#     264,
#     34377,
#     1755,
#     293,
#     2281,
#     10479,
#     11,
#     4965,
#     6465,
#     36,
#     7901,
#     10895,
#     412,
#     1025,
#     13,
#     16,
#     6856],
#    'temperature': 0.0,
#    'avg_logprob': -0.11466116375393337,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.00017902861873153597},
#   {'id': 22,
#    'seek': 17000,
#    'start': 170.0,
#    'end': 179.0,
#    'text': ' The recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services.',
#    'tokens': [440,
#     5162,
#     15860,
#     1412,
#     797,
#     362,
#     808,
#     294,
#     2946,
#     813,
#     5176,
#     13,
#     25803,
#     23573,
#     12780,
#     16371,
#     2108,
#     257,
#     4152,
#     3613,
#     295,
#     10179,
#     293,
#     3328,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09368622303009033,
#    'compression_ratio': 1.703422053231939,
#    'no_speech_prob': 0.00014583700976800174},
#   {'id': 23,
#    'seek': 17000,
#    'start': 179.0,
#    'end': 187.0,
#    'text': " Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation.",
#    'tokens': [6797,
#     311,
#     1516,
#     1970,
#     14081,
#     575,
#     9194,
#     292,
#     7901,
#     337,
#     2281,
#     293,
#     1755,
#     293,
#     575,
#     2942,
#     4497,
#     23452,
#     3321,
#     322,
#     15860,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09368622303009033,
#    'compression_ratio': 1.703422053231939,
#    'no_speech_prob': 0.00014583700976800174},
#   {'id': 24,
#    'seek': 17000,
#    'start': 187.0,
#    'end': 198.0,
#    'text': ' Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters,',
#    'tokens': [11334,
#     23457,
#     15860,
#     11,
#     2854,
#     1433,
#     15860,
#     9843,
#     4204,
#     281,
#     6222,
#     731,
#     12723,
#     2769,
#     11,
#     382,
#     15502,
#     294,
#     257,
#     4152,
#     3613,
#     295,
#     22711,
#     295,
#     22850,
#     11,
#     6011,
#     11,
#     293,
#     2091,
#     16369,
#     1559,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.09368622303009033,
#    'compression_ratio': 1.703422053231939,
#    'no_speech_prob': 0.00014583700976800174},
#   {'id': 25,
#    'seek': 19800,
#    'start': 198.0,
#    'end': 203.0,
#    'text': ' as well as measures from financial markets. That is not grounds for complacency.',
#    'tokens': [382,
#     731,
#     382,
#     8000,
#     490,
#     4669,
#     8383,
#     13,
#     663,
#     307,
#     406,
#     19196,
#     337,
#     49546,
#     3020,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06825909816043478,
#    'compression_ratio': 1.59375,
#    'no_speech_prob': 0.0003440464788582176},
#   {'id': 26,
#    'seek': 19800,
#    'start': 203.0,
#    'end': 212.0,
#    'text': ' The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched.',
#    'tokens': [440,
#     2854,
#     264,
#     2190,
#     2372,
#     295,
#     1090,
#     15860,
#     6515,
#     11,
#     264,
#     5044,
#     264,
#     2931,
#     300,
#     9843,
#     295,
#     2946,
#     15860,
#     486,
#     1813,
#     948,
#     42388,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06825909816043478,
#    'compression_ratio': 1.59375,
#    'no_speech_prob': 0.0003440464788582176},
#   {'id': 27,
#    'seek': 19800,
#    'start': 212.0,
#    'end': 220.0,
#    'text': " The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people.",
#    'tokens': [440,
#     7772,
#     311,
#     26388,
#     3897,
#     5909,
#     366,
#     19663,
#     538,
#     527,
#     23885,
#     281,
#     9773,
#     6674,
#     11949,
#     293,
#     8351,
#     7901,
#     337,
#     264,
#     2665,
#     561,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06825909816043478,
#    'compression_ratio': 1.59375,
#    'no_speech_prob': 0.0003440464788582176},
#   {'id': 28,
#    'seek': 22000,
#    'start': 220.0,
#    'end': 235.0,
#    'text': " My colleagues and I are acutely aware that high inflation imposes significant hardship and is at erode's purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation.",
#    'tokens': [1222,
#     7734,
#     293,
#     286,
#     366,
#     696,
#     325,
#     736,
#     3650,
#     300,
#     1090,
#     15860,
#     704,
#     4201,
#     4776,
#     24172,
#     293,
#     307,
#     412,
#     1189,
#     1429,
#     311,
#     20906,
#     1347,
#     11,
#     2318,
#     337,
#     729,
#     1935,
#     1075,
#     281,
#     1677,
#     264,
#     2946,
#     5497,
#     295,
#     46884,
#     411,
#     1755,
#     11,
#     6849,
#     11,
#     293,
#     11328,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08374620920204255,
#    'compression_ratio': 1.6556016597510372,
#    'no_speech_prob': 0.00016037006571423262},
#   {'id': 29,
#    'seek': 22000,
#    'start': 235.0,
#    'end': 246.0,
#    'text': " We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective.",
#    'tokens': [492,
#     366,
#     5405,
#     43661,
#     281,
#     264,
#     10888,
#     300,
#     1090,
#     15860,
#     26059,
#     281,
#     1293,
#     4881,
#     295,
#     527,
#     23885,
#     11,
#     293,
#     321,
#     434,
#     10613,
#     7784,
#     281,
#     12678,
#     15860,
#     281,
#     527,
#     568,
#     4,
#     10024,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08374620920204255,
#    'compression_ratio': 1.6556016597510372,
#    'no_speech_prob': 0.00016037006571423262},
#   {'id': 30,
#    'seek': 24600,
#    'start': 246.0,
#    'end': 261.0,
#    'text': " At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points, and we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in firming the stance of monetary policy.",
#    'tokens': [1711,
#     965,
#     311,
#     3440,
#     11,
#     264,
#     7482,
#     6005,
#     264,
#     3779,
#     3613,
#     337,
#     264,
#     6019,
#     8271,
#     3314,
#     538,
#     9562,
#     5143,
#     2793,
#     11,
#     293,
#     321,
#     366,
#     9289,
#     264,
#     1399,
#     295,
#     10591,
#     12245,
#     264,
#     2744,
#     295,
#     527,
#     4772,
#     8193,
#     11,
#     597,
#     5749,
#     364,
#     1021,
#     3090,
#     294,
#     12159,
#     2810,
#     264,
#     21033,
#     295,
#     26388,
#     3897,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.12075371619982597,
#    'compression_ratio': 1.58008658008658,
#    'no_speech_prob': 0.0003452427336014807},
#   {'id': 31,
#    'seek': 24600,
#    'start': 261.0,
#    'end': 268.0,
#    'text': " With today's action, we've raised interest rates by 3 and 3-quarters percentage points this year.",
#    'tokens': [2022,
#     965,
#     311,
#     3069,
#     11,
#     321,
#     600,
#     6005,
#     1179,
#     6846,
#     538,
#     805,
#     293,
#     805,
#     12,
#     17313,
#     9668,
#     2793,
#     341,
#     1064,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.12075371619982597,
#    'compression_ratio': 1.58008658008658,
#    'no_speech_prob': 0.0003452427336014807},
#   {'id': 32,
#    'seek': 26800,
#    'start': 268.0,
#    'end': 281.0,
#    'text': ' We anticipate that ongoing increases in the target range for the federal funds rate will be appropriate in order to attain a stance of monetary policy that is sufficiently restrictive to return inflation to 2% over time.',
#    'tokens': [492,
#     21685,
#     300,
#     10452,
#     8637,
#     294,
#     264,
#     3779,
#     3613,
#     337,
#     264,
#     6019,
#     8271,
#     3314,
#     486,
#     312,
#     6854,
#     294,
#     1668,
#     281,
#     23766,
#     257,
#     21033,
#     295,
#     26388,
#     3897,
#     300,
#     307,
#     31868,
#     43220,
#     281,
#     2736,
#     15860,
#     281,
#     568,
#     4,
#     670,
#     565,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.049927559494972226,
#    'compression_ratio': 1.6484375,
#    'no_speech_prob': 9.450737707084045e-05},
#   {'id': 33,
#    'seek': 26800,
#    'start': 281.0,
#    'end': 291.0,
#    'text': ' Financial conditions have tightened significantly in response to our policy actions, and we are seeing the effects on demand in the most interest rate sensitive sectors of the economy, such as housing.',
#    'tokens': [25560,
#     4487,
#     362,
#     49673,
#     10591,
#     294,
#     4134,
#     281,
#     527,
#     3897,
#     5909,
#     11,
#     293,
#     321,
#     366,
#     2577,
#     264,
#     5065,
#     322,
#     4733,
#     294,
#     264,
#     881,
#     1179,
#     3314,
#     9477,
#     18373,
#     295,
#     264,
#     5010,
#     11,
#     1270,
#     382,
#     6849,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.049927559494972226,
#    'compression_ratio': 1.6484375,
#    'no_speech_prob': 9.450737707084045e-05},
#   {'id': 34,
#    'seek': 29100,
#    'start': 291.0,
#    'end': 298.0,
#    'text': ' It will take time, however, for the full effects of monetary restraint to be realized, especially on inflation.',
#    'tokens': [467,
#     486,
#     747,
#     565,
#     11,
#     4461,
#     11,
#     337,
#     264,
#     1577,
#     5065,
#     295,
#     26388,
#     49281,
#     281,
#     312,
#     5334,
#     11,
#     2318,
#     322,
#     15860,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.04512661856573981,
#    'compression_ratio': 1.6727272727272726,
#    'no_speech_prob': 0.0002903198474086821},
#   {'id': 35,
#    'seek': 29100,
#    'start': 298.0,
#    'end': 312.0,
#    'text': " That's why we say in our statement that in determining the pace of future increases in the target range, we will take into account the cumulative tightening of monetary policy and the lags with which monetary policy affects economic activity and inflation.",
#    'tokens': [663,
#     311,
#     983,
#     321,
#     584,
#     294,
#     527,
#     5629,
#     300,
#     294,
#     23751,
#     264,
#     11638,
#     295,
#     2027,
#     8637,
#     294,
#     264,
#     3779,
#     3613,
#     11,
#     321,
#     486,
#     747,
#     666,
#     2696,
#     264,
#     38379,
#     42217,
#     295,
#     26388,
#     3897,
#     293,
#     264,
#     8953,
#     82,
#     365,
#     597,
#     26388,
#     3897,
#     11807,
#     4836,
#     5191,
#     293,
#     15860,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.04512661856573981,
#    'compression_ratio': 1.6727272727272726,
#    'no_speech_prob': 0.0002903198474086821},
#   {'id': 36,
#    'seek': 31200,
#    'start': 312.0,
#    'end': 325.0,
#    'text': " At some point, as I've said in the last two press conferences, it will become appropriate to slow the pace of increases, as we approach the level of interest rates that will be sufficiently restrictive to bring inflation down to our 2% goal.",
#    'tokens': [1711,
#     512,
#     935,
#     11,
#     382,
#     286,
#     600,
#     848,
#     294,
#     264,
#     1036,
#     732,
#     1886,
#     22032,
#     11,
#     309,
#     486,
#     1813,
#     6854,
#     281,
#     2964,
#     264,
#     11638,
#     295,
#     8637,
#     11,
#     382,
#     321,
#     3109,
#     264,
#     1496,
#     295,
#     1179,
#     6846,
#     300,
#     486,
#     312,
#     31868,
#     43220,
#     281,
#     1565,
#     15860,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.047421115817445694,
#    'compression_ratio': 1.6030927835051547,
#    'no_speech_prob': 7.463931251550093e-05},
#   {'id': 37,
#    'seek': 31200,
#    'start': 325.0,
#    'end': 330.0,
#    'text': ' There is significant uncertainty around that level of interest rates.',
#    'tokens': [821, 307, 4776, 15697, 926, 300, 1496, 295, 1179, 6846, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.047421115817445694,
#    'compression_ratio': 1.6030927835051547,
#    'no_speech_prob': 7.463931251550093e-05},
#   {'id': 38,
#    'seek': 33000,
#    'start': 330.0,
#    'end': 342.0,
#    'text': ' Even so, we still have some ways to go, and incoming data since our last meeting suggests that the ultimate level of interest rates will be higher than previously expected.',
#    'tokens': [2754,
#     370,
#     11,
#     321,
#     920,
#     362,
#     512,
#     2098,
#     281,
#     352,
#     11,
#     293,
#     22341,
#     1412,
#     1670,
#     527,
#     1036,
#     3440,
#     13409,
#     300,
#     264,
#     9705,
#     1496,
#     295,
#     1179,
#     6846,
#     486,
#     312,
#     2946,
#     813,
#     8046,
#     5176,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06100991835077125,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.00010856004519155249},
#   {'id': 39,
#    'seek': 33000,
#    'start': 342.0,
#    'end': 349.0,
#    'text': ' Our decisions will depend on the totality of incoming data and their implications for the outlook for economic activity and inflation.',
#    'tokens': [2621,
#     5327,
#     486,
#     5672,
#     322,
#     264,
#     1993,
#     1860,
#     295,
#     22341,
#     1412,
#     293,
#     641,
#     16602,
#     337,
#     264,
#     26650,
#     337,
#     4836,
#     5191,
#     293,
#     15860,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06100991835077125,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.00010856004519155249},
#   {'id': 40,
#    'seek': 33000,
#    'start': 349.0,
#    'end': 355.0,
#    'text': ' We will continue to make our decisions meeting by being and communicate our thinking as clearly as possible.',
#    'tokens': [492,
#     486,
#     2354,
#     281,
#     652,
#     527,
#     5327,
#     3440,
#     538,
#     885,
#     293,
#     7890,
#     527,
#     1953,
#     382,
#     4448,
#     382,
#     1944,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.06100991835077125,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.00010856004519155249},
#   {'id': 41,
#    'seek': 35500,
#    'start': 355.0,
#    'end': 360.0,
#    'text': " We're taking forceful steps to moderate demand so that it comes into better alignment with supply.",
#    'tokens': [492,
#     434,
#     1940,
#     3464,
#     906,
#     4439,
#     281,
#     18174,
#     4733,
#     370,
#     300,
#     309,
#     1487,
#     666,
#     1101,
#     18515,
#     365,
#     5847,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.05166846890992756,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.0001734936231514439},
#   {'id': 42,
#    'seek': 35500,
#    'start': 360.0,
#    'end': 370.0,
#    'text': ' Our overarching focus is using our tools to bring inflation back down to our 2% goal and to keep longer term inflation expectations well anchored.',
#    'tokens': [2621,
#     45501,
#     1879,
#     307,
#     1228,
#     527,
#     3873,
#     281,
#     1565,
#     15860,
#     646,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     293,
#     281,
#     1066,
#     2854,
#     1433,
#     15860,
#     9843,
#     731,
#     12723,
#     2769,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.05166846890992756,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.0001734936231514439},
#   {'id': 43,
#    'seek': 35500,
#    'start': 370.0,
#    'end': 379.0,
#    'text': ' Reducing inflation is likely to require a sustained period of below trend growth and some softening of labor market conditions.',
#    'tokens': [4477,
#     1311,
#     278,
#     15860,
#     307,
#     3700,
#     281,
#     3651,
#     257,
#     23389,
#     2896,
#     295,
#     2507,
#     6028,
#     4599,
#     293,
#     512,
#     2787,
#     4559,
#     295,
#     5938,
#     2142,
#     4487,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.05166846890992756,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.0001734936231514439},
#   {'id': 44,
#    'seek': 37900,
#    'start': 379.0,
#    'end': 386.0,
#    'text': ' Restoring price stability is essential to set the stage for achieving maximum employment and stable prices in the longer run.',
#    'tokens': [13094,
#     3662,
#     3218,
#     11826,
#     307,
#     7115,
#     281,
#     992,
#     264,
#     3233,
#     337,
#     19626,
#     6674,
#     11949,
#     293,
#     8351,
#     7901,
#     294,
#     264,
#     2854,
#     1190,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.051298302273417626,
#    'compression_ratio': 1.5992217898832686,
#    'no_speech_prob': 0.0003394588129594922},
#   {'id': 45,
#    'seek': 37900,
#    'start': 386.0,
#    'end': 391.0,
#    'text': ' The historical record caution strongly against prematurely loosening policy.',
#    'tokens': [440,
#     8584,
#     2136,
#     23585,
#     10613,
#     1970,
#     34877,
#     356,
#     40454,
#     4559,
#     3897,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.051298302273417626,
#    'compression_ratio': 1.5992217898832686,
#    'no_speech_prob': 0.0003394588129594922},
#   {'id': 46,
#    'seek': 37900,
#    'start': 391.0,
#    'end': 394.0,
#    'text': ' We will stay the course until the job is done.',
#    'tokens': [492, 486, 1754, 264, 1164, 1826, 264, 1691, 307, 1096, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.051298302273417626,
#    'compression_ratio': 1.5992217898832686,
#    'no_speech_prob': 0.0003394588129594922},
#   {'id': 47,
#    'seek': 37900,
#    'start': 394.0,
#    'end': 400.0,
#    'text': ' To conclude, we understand that our actions affect communities, families and businesses across the country.',
#    'tokens': [1407,
#     16886,
#     11,
#     321,
#     1223,
#     300,
#     527,
#     5909,
#     3345,
#     4456,
#     11,
#     4466,
#     293,
#     6011,
#     2108,
#     264,
#     1941,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.051298302273417626,
#    'compression_ratio': 1.5992217898832686,
#    'no_speech_prob': 0.0003394588129594922},
#   {'id': 48,
#    'seek': 37900,
#    'start': 400.0,
#    'end': 404.0,
#    'text': ' Everything we do is in service to our public mission.',
#    'tokens': [5471, 321, 360, 307, 294, 2643, 281, 527, 1908, 4447, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.051298302273417626,
#    'compression_ratio': 1.5992217898832686,
#    'no_speech_prob': 0.0003394588129594922},
#   {'id': 49,
#    'seek': 40400,
#    'start': 404.0,
#    'end': 410.0,
#    'text': ' We at the Fed will do everything we can to achieve our maximum employment and price stability goals.',
#    'tokens': [492,
#     412,
#     264,
#     7772,
#     486,
#     360,
#     1203,
#     321,
#     393,
#     281,
#     4584,
#     527,
#     6674,
#     11949,
#     293,
#     3218,
#     11826,
#     5493,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 50,
#    'seek': 40400,
#    'start': 410.0,
#    'end': 413.0,
#    'text': ' Thank you and I look forward to your questions.',
#    'tokens': [1044, 291, 293, 286, 574, 2128, 281, 428, 1651, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 51,
#    'seek': 40400,
#    'start': 413.0,
#    'end': 417.0,
#    'text': ' Thank you, Colby.',
#    'tokens': [1044, 291, 11, 4004, 2322, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 52,
#    'seek': 40400,
#    'start': 417.0,
#    'end': 420.0,
#    'text': ' Thank you. Colby Smith with the Financial Times.',
#    'tokens': [1044, 291, 13, 4004, 2322, 8538, 365, 264, 25560, 11366, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 53,
#    'seek': 40400,
#    'start': 420.0,
#    'end': 423.0,
#    'text': ' On the need to slow the pace of rate increases at some point.',
#    'tokens': [1282,
#     264,
#     643,
#     281,
#     2964,
#     264,
#     11638,
#     295,
#     3314,
#     8637,
#     412,
#     512,
#     935,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 54,
#    'seek': 40400,
#    'start': 423.0,
#    'end': 431.0,
#    'text': " Is a is a downshift contingent on a string of better inflation data specifically between now and let's say the December meeting?",
#    'tokens': [1119,
#     257,
#     307,
#     257,
#     760,
#     47445,
#     27820,
#     317,
#     322,
#     257,
#     6798,
#     295,
#     1101,
#     15860,
#     1412,
#     4682,
#     1296,
#     586,
#     293,
#     718,
#     311,
#     584,
#     264,
#     7687,
#     3440,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.11557177543640136,
#    'compression_ratio': 1.573643410852713,
#    'no_speech_prob': 0.000559836276806891},
#   {'id': 55,
#    'seek': 43100,
#    'start': 431.0,
#    'end': 439.0,
#    'text': ' Is that something that the Fed could potentially proceed with independent of that data given the lag defects that you mentioned?',
#    'tokens': [1119,
#     300,
#     746,
#     300,
#     264,
#     7772,
#     727,
#     7263,
#     8991,
#     365,
#     6695,
#     295,
#     300,
#     1412,
#     2212,
#     264,
#     8953,
#     32655,
#     300,
#     291,
#     2835,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.10891240781491941,
#    'compression_ratio': 1.745644599303136,
#    'no_speech_prob': 0.0004565146518871188},
#   {'id': 56,
#    'seek': 43100,
#    'start': 439.0,
#    'end': 442.0,
#    'text': ' So a couple of things on that.',
#    'tokens': [407, 257, 1916, 295, 721, 322, 300, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10891240781491941,
#    'compression_ratio': 1.745644599303136,
#    'no_speech_prob': 0.0004565146518871188},
#   {'id': 57,
#    'seek': 43100,
#    'start': 442.0,
#    'end': 449.0,
#    'text': ' We do need to see inflation coming down decisively and good at evidence of that would be a series of down monthly readings.',
#    'tokens': [492,
#     360,
#     643,
#     281,
#     536,
#     15860,
#     1348,
#     760,
#     18206,
#     3413,
#     293,
#     665,
#     412,
#     4467,
#     295,
#     300,
#     576,
#     312,
#     257,
#     2638,
#     295,
#     760,
#     12878,
#     27319,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10891240781491941,
#    'compression_ratio': 1.745644599303136,
#    'no_speech_prob': 0.0004565146518871188},
#   {'id': 58,
#    'seek': 43100,
#    'start': 449.0,
#    'end': 451.0,
#    'text': " Of course that's what we'd all love to see.",
#    'tokens': [2720, 1164, 300, 311, 437, 321, 1116, 439, 959, 281, 536, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10891240781491941,
#    'compression_ratio': 1.745644599303136,
#    'no_speech_prob': 0.0004565146518871188},
#   {'id': 59,
#    'seek': 43100,
#    'start': 451.0,
#    'end': 460.0,
#    'text': " But that's I've never thought of that as the appropriate test for slowing the pace of increases or for identifying the appropriately restrictive level that we're aiming for.",
#    'tokens': [583,
#     300,
#     311,
#     286,
#     600,
#     1128,
#     1194,
#     295,
#     300,
#     382,
#     264,
#     6854,
#     1500,
#     337,
#     26958,
#     264,
#     11638,
#     295,
#     8637,
#     420,
#     337,
#     16696,
#     264,
#     23505,
#     43220,
#     1496,
#     300,
#     321,
#     434,
#     20253,
#     337,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10891240781491941,
#    'compression_ratio': 1.745644599303136,
#    'no_speech_prob': 0.0004565146518871188},
#   {'id': 60,
#    'seek': 46000,
#    'start': 460.0,
#    'end': 468.0,
#    'text': " We need to bring our policy stance down to a level that's sufficiently restrictive to bring inflation down to our 2% objective over the medium term.",
#    'tokens': [492,
#     643,
#     281,
#     1565,
#     527,
#     3897,
#     21033,
#     760,
#     281,
#     257,
#     1496,
#     300,
#     311,
#     31868,
#     43220,
#     281,
#     1565,
#     15860,
#     760,
#     281,
#     527,
#     568,
#     4,
#     10024,
#     670,
#     264,
#     6399,
#     1433,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08687067914892126,
#    'compression_ratio': 1.6711409395973154,
#    'no_speech_prob': 0.00026084622368216515},
#   {'id': 61,
#    'seek': 46000,
#    'start': 468.0,
#    'end': 470.0,
#    'text': " How will we know that we've reached that level?",
#    'tokens': [1012, 486, 321, 458, 300, 321, 600, 6488, 300, 1496, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.08687067914892126,
#    'compression_ratio': 1.6711409395973154,
#    'no_speech_prob': 0.00026084622368216515},
#   {'id': 62,
#    'seek': 46000,
#    'start': 470.0,
#    'end': 478.0,
#    'text': " Well, we'll take into account the full range of analysis and data that bear on that question guided by our assessment of how much financial conditions have tightened.",
#    'tokens': [1042,
#     11,
#     321,
#     603,
#     747,
#     666,
#     2696,
#     264,
#     1577,
#     3613,
#     295,
#     5215,
#     293,
#     1412,
#     300,
#     6155,
#     322,
#     300,
#     1168,
#     19663,
#     538,
#     527,
#     9687,
#     295,
#     577,
#     709,
#     4669,
#     4487,
#     362,
#     49673,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08687067914892126,
#    'compression_ratio': 1.6711409395973154,
#    'no_speech_prob': 0.00026084622368216515},
#   {'id': 63,
#    'seek': 46000,
#    'start': 478.0,
#    'end': 483.0,
#    'text': ' The effects of that tightening is actually having on the real economy and on inflation.',
#    'tokens': [440,
#     5065,
#     295,
#     300,
#     42217,
#     307,
#     767,
#     1419,
#     322,
#     264,
#     957,
#     5010,
#     293,
#     322,
#     15860,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08687067914892126,
#    'compression_ratio': 1.6711409395973154,
#    'no_speech_prob': 0.00026084622368216515},
#   {'id': 64,
#    'seek': 46000,
#    'start': 483.0,
#    'end': 486.0,
#    'text': ' Taking into consideration lags as I mentioned.',
#    'tokens': [17837, 666, 12381, 8953, 82, 382, 286, 2835, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08687067914892126,
#    'compression_ratio': 1.6711409395973154,
#    'no_speech_prob': 0.00026084622368216515},
#   {'id': 65,
#    'seek': 48600,
#    'start': 486.0,
#    'end': 493.0,
#    'text': ' We will be looking at real rates, for example, all across the yield curve and all other financial conditions.',
#    'tokens': [492,
#     486,
#     312,
#     1237,
#     412,
#     957,
#     6846,
#     11,
#     337,
#     1365,
#     11,
#     439,
#     2108,
#     264,
#     11257,
#     7605,
#     293,
#     439,
#     661,
#     4669,
#     4487,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.18498695775082236,
#    'compression_ratio': 1.565040650406504,
#    'no_speech_prob': 0.00046514946734532714},
#   {'id': 66,
#    'seek': 48600,
#    'start': 493.0,
#    'end': 496.0,
#    'text': ' And as we make that assessment.',
#    'tokens': [400, 382, 321, 652, 300, 9687, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.18498695775082236,
#    'compression_ratio': 1.565040650406504,
#    'no_speech_prob': 0.00046514946734532714},
#   {'id': 67,
#    'seek': 48600,
#    'start': 496.0,
#    'end': 502.0,
#    'text': ' I wish neither with with rotors.',
#    'tokens': [286, 3172, 9662, 365, 365, 4297, 830, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.18498695775082236,
#    'compression_ratio': 1.565040650406504,
#    'no_speech_prob': 0.00046514946734532714},
#   {'id': 68,
#    'seek': 48600,
#    'start': 502.0,
#    'end': 508.0,
#    'text': " Look, I'm sure there's going to be tons of confusion out there about whether this means you're going to slow in December or not.",
#    'tokens': [2053,
#     11,
#     286,
#     478,
#     988,
#     456,
#     311,
#     516,
#     281,
#     312,
#     9131,
#     295,
#     15075,
#     484,
#     456,
#     466,
#     1968,
#     341,
#     1355,
#     291,
#     434,
#     516,
#     281,
#     2964,
#     294,
#     7687,
#     420,
#     406,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.18498695775082236,
#    'compression_ratio': 1.565040650406504,
#    'no_speech_prob': 0.00046514946734532714},
#   {'id': 69,
#    'seek': 48600,
#    'start': 508.0,
#    'end': 513.0,
#    'text': ' Would you say that the bias right now is not for another 75 basis point increase?',
#    'tokens': [6068,
#     291,
#     584,
#     300,
#     264,
#     12577,
#     558,
#     586,
#     307,
#     406,
#     337,
#     1071,
#     9562,
#     5143,
#     935,
#     3488,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.18498695775082236,
#    'compression_ratio': 1.565040650406504,
#    'no_speech_prob': 0.00046514946734532714},
#   {'id': 70,
#    'seek': 51300,
#    'start': 513.0,
#    'end': 523.0,
#    'text': ' So what I want to do is put that question of pace in the context of our broader tightening program of fine-day.',
#    'tokens': [407,
#     437,
#     286,
#     528,
#     281,
#     360,
#     307,
#     829,
#     300,
#     1168,
#     295,
#     11638,
#     294,
#     264,
#     4319,
#     295,
#     527,
#     13227,
#     42217,
#     1461,
#     295,
#     2489,
#     12,
#     810,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 71,
#    'seek': 51300,
#    'start': 523.0,
#    'end': 526.0,
#    'text': ' And to talk about the statement language along the way.',
#    'tokens': [400, 281, 751, 466, 264, 5629, 2856, 2051, 264, 636, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 72,
#    'seek': 51300,
#    'start': 526.0,
#    'end': 531.0,
#    'text': ' So I think you can think about our tightening program as really addressing three questions.',
#    'tokens': [407,
#     286,
#     519,
#     291,
#     393,
#     519,
#     466,
#     527,
#     42217,
#     1461,
#     382,
#     534,
#     14329,
#     1045,
#     1651,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 73,
#    'seek': 51300,
#    'start': 531.0,
#    'end': 534.0,
#    'text': ' The first of which was and has been how fast to go.',
#    'tokens': [440, 700, 295, 597, 390, 293, 575, 668, 577, 2370, 281, 352, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 74,
#    'seek': 51300,
#    'start': 534.0,
#    'end': 537.0,
#    'text': ' The second is how high to raise our policy rate.',
#    'tokens': [440, 1150, 307, 577, 1090, 281, 5300, 527, 3897, 3314, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 75,
#    'seek': 51300,
#    'start': 537.0,
#    'end': 542.0,
#    'text': ' And the third will be eventually how long to remain at a restrictive level.',
#    'tokens': [400,
#     264,
#     2636,
#     486,
#     312,
#     4728,
#     577,
#     938,
#     281,
#     6222,
#     412,
#     257,
#     43220,
#     1496,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14250679016113282,
#    'compression_ratio': 1.6964980544747081,
#    'no_speech_prob': 0.0003001739678438753},
#   {'id': 76,
#    'seek': 54200,
#    'start': 542.0,
#    'end': 546.0,
#    'text': ' On the first question, how fast to tighten policy.',
#    'tokens': [1282, 264, 700, 1168, 11, 577, 2370, 281, 17041, 3897, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09875867051898309,
#    'compression_ratio': 1.667883211678832,
#    'no_speech_prob': 0.00014638992433901876},
#   {'id': 77,
#    'seek': 54200,
#    'start': 546.0,
#    'end': 550.0,
#    'text': " It's been very important that we move expeditiously and we have clearly done so.",
#    'tokens': [467,
#     311,
#     668,
#     588,
#     1021,
#     300,
#     321,
#     1286,
#     19348,
#     270,
#     8994,
#     293,
#     321,
#     362,
#     4448,
#     1096,
#     370,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09875867051898309,
#    'compression_ratio': 1.667883211678832,
#    'no_speech_prob': 0.00014638992433901876},
#   {'id': 78,
#    'seek': 54200,
#    'start': 550.0,
#    'end': 555.0,
#    'text': " We've moved three and three quarters percent since March, admittedly from a base of zero.",
#    'tokens': [492,
#     600,
#     4259,
#     1045,
#     293,
#     1045,
#     20612,
#     3043,
#     1670,
#     6129,
#     11,
#     14920,
#     356,
#     490,
#     257,
#     3096,
#     295,
#     4018,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.09875867051898309,
#    'compression_ratio': 1.667883211678832,
#    'no_speech_prob': 0.00014638992433901876},
#   {'id': 79,
#    'seek': 54200,
#    'start': 555.0,
#    'end': 564.0,
#    'text': " It's a historically fast pace and that's certainly appropriate given the persistence and strength and inflation and the low level from which we started.",
#    'tokens': [467,
#     311,
#     257,
#     16180,
#     2370,
#     11638,
#     293,
#     300,
#     311,
#     3297,
#     6854,
#     2212,
#     264,
#     37617,
#     293,
#     3800,
#     293,
#     15860,
# ...
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 671,
#    'seek': 256640,
#    'start': 2577.6,
#    'end': 2582.32,
#    'text': ' and stay higher for longer, it becomes harder to see the path.',
#    'tokens': [293,
#     1754,
#     2946,
#     337,
#     2854,
#     11,
#     309,
#     3643,
#     6081,
#     281,
#     536,
#     264,
#     3100,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 672,
#    'seek': 256640,
#    'start': 2582.32,
#    'end': 2583.32,
#    'text': " It's narrowed.",
#    'tokens': [467, 311, 9432, 292, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 673,
#    'seek': 256640,
#    'start': 2583.32,
#    'end': 2585.8,
#    'text': ' I would say the path is narrowed over the course of the last year,',
#    'tokens': [286,
#     576,
#     584,
#     264,
#     3100,
#     307,
#     9432,
#     292,
#     670,
#     264,
#     1164,
#     295,
#     264,
#     1036,
#     1064,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 674,
#    'seek': 256640,
#    'start': 2585.8,
#    'end': 2586.64,
#    'text': ' really.',
#    'tokens': [534, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 675,
#    'seek': 256640,
#    'start': 2587.88,
#    'end': 2589.36,
#    'text': ' Hard to say, hard to say.',
#    'tokens': [11817, 281, 584, 11, 1152, 281, 584, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 676,
#    'seek': 256640,
#    'start': 2589.36,
#    'end': 2594.36,
#    'text': ' You know, again, I would say that the sort of array of data',
#    'tokens': [509,
#     458,
#     11,
#     797,
#     11,
#     286,
#     576,
#     584,
#     300,
#     264,
#     1333,
#     295,
#     10225,
#     295,
#     1412],
#    'temperature': 0.0,
#    'avg_logprob': -0.21552861638429785,
#    'compression_ratio': 1.6853448275862069,
#    'no_speech_prob': 0.0001534246257506311},
#   {'id': 677,
#    'seek': 259436,
#    'start': 2594.36,
#    'end': 2599.36,
#    'text': ' in the labor market is highly unusual, and to many economists,',
#    'tokens': [294,
#     264,
#     5938,
#     2142,
#     307,
#     5405,
#     10901,
#     11,
#     293,
#     281,
#     867,
#     32431,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 678,
#    'seek': 259436,
#    'start': 2599.36,
#    'end': 2603.36,
#    'text': " there is a path to, there's an ordinarial,",
#    'tokens': [456,
#     307,
#     257,
#     3100,
#     281,
#     11,
#     456,
#     311,
#     364,
#     4792,
#     6470,
#     831,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 679,
#    'seek': 259436,
#    'start': 2603.36,
#    'end': 2607.36,
#    'text': " there's a relationship to GP going down",
#    'tokens': [456, 311, 257, 2480, 281, 26039, 516, 760],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 680,
#    'seek': 259436,
#    'start': 2607.36,
#    'end': 2612.36,
#    'text': ' and vacancies declining, translating into unemployment,',
#    'tokens': [293, 2842, 32286, 34298, 11, 35030, 666, 17438, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 681,
#    'seek': 259436,
#    'start': 2613.36,
#    'end': 2614.36,
#    'text': " or there's Oaken's law.",
#    'tokens': [420, 456, 311, 422, 9846, 311, 2101, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 682,
#    'seek': 259436,
#    'start': 2614.36,
#    'end': 2617.36,
#    'text': ' So all those things are relationships that are in the data',
#    'tokens': [407, 439, 729, 721, 366, 6159, 300, 366, 294, 264, 1412],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 683,
#    'seek': 259436,
#    'start': 2617.36,
#    'end': 2618.36,
#    'text': " and they're very real.",
#    'tokens': [293, 436, 434, 588, 957, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 684,
#    'seek': 259436,
#    'start': 2618.36,
#    'end': 2620.36,
#    'text': " There's a little bit different this time, though,",
#    'tokens': [821, 311, 257, 707, 857, 819, 341, 565, 11, 1673, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 685,
#    'seek': 259436,
#    'start': 2620.36,
#    'end': 2623.36,
#    'text': ' because you have this tremendously high level of vacancies,',
#    'tokens': [570, 291, 362, 341, 27985, 1090, 1496, 295, 2842, 32286, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.3155770041725852,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.00018217743490822613},
#   {'id': 686,
#    'seek': 262336,
#    'start': 2623.36,
#    'end': 2626.36,
#    'text': ' we think on a very steep part of the beverage curve,',
#    'tokens': [321, 519, 322, 257, 588, 16841, 644, 295, 264, 35519, 7605, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 687,
#    'seek': 262336,
#    'start': 2626.36,
#    'end': 2631.36,
#    'text': ' all I would say is that the job losses may turn out',
#    'tokens': [439, 286, 576, 584, 307, 300, 264, 1691, 15352, 815, 1261, 484],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 688,
#    'seek': 262336,
#    'start': 2631.36,
#    'end': 2635.36,
#    'text': ' to be less than would be indicated by those traditional measures',
#    'tokens': [281, 312, 1570, 813, 576, 312, 16176, 538, 729, 5164, 8000],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 689,
#    'seek': 262336,
#    'start': 2635.36,
#    'end': 2638.36,
#    'text': ' because job openings are so elevated',
#    'tokens': [570, 1691, 35941, 366, 370, 23457],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 690,
#    'seek': 262336,
#    'start': 2638.36,
#    'end': 2641.36,
#    'text': ' and because the labor market is so strong.',
#    'tokens': [293, 570, 264, 5938, 2142, 307, 370, 2068, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 691,
#    'seek': 262336,
#    'start': 2641.36,
#    'end': 2644.36,
#    'text': " Again, that's gonna be something we discover empirically.",
#    'tokens': [3764, 11, 300, 311, 799, 312, 746, 321, 4411, 25790, 984, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 692,
#    'seek': 262336,
#    'start': 2644.36,
#    'end': 2648.36,
#    'text': " I think no one knows whether there's gonna be a recession",
#    'tokens': [286, 519, 572, 472, 3255, 1968, 456, 311, 799, 312, 257, 24828],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 693,
#    'seek': 262336,
#    'start': 2648.36,
#    'end': 2652.36,
#    'text': ' or not, and if so, how bad that recession would be,',
#    'tokens': [420,
#     406,
#     11,
#     293,
#     498,
#     370,
#     11,
#     577,
#     1578,
#     300,
#     24828,
#     576,
#     312,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.08118500799502966,
#    'compression_ratio': 1.6746987951807228,
#    'no_speech_prob': 0.0002487102465238422},
#   {'id': 694,
#    'seek': 265236,
#    'start': 2652.36,
#    'end': 2657.36,
#    'text': ' and our job is to restore price stability',
#    'tokens': [293, 527, 1691, 307, 281, 15227, 3218, 11826],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 695,
#    'seek': 265236,
#    'start': 2657.36,
#    'end': 2659.36,
#    'text': ' so that we can have a strong labor market',
#    'tokens': [370, 300, 321, 393, 362, 257, 2068, 5938, 2142],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 696,
#    'seek': 265236,
#    'start': 2659.36,
#    'end': 2662.36,
#    'text': " that benefits all over time, and that's what we're gonna do.",
#    'tokens': [300,
#     5311,
#     439,
#     670,
#     565,
#     11,
#     293,
#     300,
#     311,
#     437,
#     321,
#     434,
#     799,
#     360,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 697,
#    'seek': 265236,
#    'start': 2662.36,
#    'end': 2666.36,
#    'text': ' Just real quickly, why do you feel like the window is narrowed?',
#    'tokens': [1449,
#     957,
#     2661,
#     11,
#     983,
#     360,
#     291,
#     841,
#     411,
#     264,
#     4910,
#     307,
#     9432,
#     292,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 698,
#    'seek': 265236,
#    'start': 2666.36,
#    'end': 2670.36,
#    'text': " Because we haven't seen inflation coming down.",
#    'tokens': [1436, 321, 2378, 380, 1612, 15860, 1348, 760, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 699,
#    'seek': 265236,
#    'start': 2670.36,
#    'end': 2673.36,
#    'text': ' The implication of inflation not coming down,',
#    'tokens': [440, 37814, 295, 15860, 406, 1348, 760, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 700,
#    'seek': 265236,
#    'start': 2673.36,
#    'end': 2676.36,
#    'text': ' and what we would expect by now to have seen',
#    'tokens': [293, 437, 321, 576, 2066, 538, 586, 281, 362, 1612],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 701,
#    'seek': 265236,
#    'start': 2676.36,
#    'end': 2681.36,
#    'text': ' is that really as a supply side, problems had resolved themselves.',
#    'tokens': [307,
#     300,
#     534,
#     382,
#     257,
#     5847,
#     1252,
#     11,
#     2740,
#     632,
#     20772,
#     2969,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.12270552317301432,
#    'compression_ratio': 1.619607843137255,
#    'no_speech_prob': 0.0005027619772590697},
#   {'id': 702,
#    'seek': 268136,
#    'start': 2681.36,
#    'end': 2685.36,
#    'text': ' We would have expected goods inflation to come down by now,',
#    'tokens': [492, 576, 362, 5176, 10179, 15860, 281, 808, 760, 538, 586, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 703,
#    'seek': 268136,
#    'start': 2685.36,
#    'end': 2688.36,
#    'text': " long since by now, and it really hasn't,",
#    'tokens': [938, 1670, 538, 586, 11, 293, 309, 534, 6132, 380, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 704,
#    'seek': 268136,
#    'start': 2688.36,
#    'end': 2690.36,
#    'text': " although it's actually it has come down,",
#    'tokens': [4878, 309, 311, 767, 309, 575, 808, 760, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 705,
#    'seek': 268136,
#    'start': 2690.36,
#    'end': 2692.36,
#    'text': " but it's not to the extent we had hoped.",
#    'tokens': [457, 309, 311, 406, 281, 264, 8396, 321, 632, 19737, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 706,
#    'seek': 268136,
#    'start': 2692.36,
#    'end': 2695.36,
#    'text': ' At the same time, now you see services inflation,',
#    'tokens': [1711, 264, 912, 565, 11, 586, 291, 536, 3328, 15860, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 707,
#    'seek': 268136,
#    'start': 2695.36,
#    'end': 2697.36,
#    'text': ' core services inflation moving up,',
#    'tokens': [4965, 3328, 15860, 2684, 493, 11],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 708,
#    'seek': 268136,
#    'start': 2697.36,
#    'end': 2701.36,
#    'text': ' and I just think that the inflation picture',
#    'tokens': [293, 286, 445, 519, 300, 264, 15860, 3036],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 709,
#    'seek': 268136,
#    'start': 2701.36,
#    'end': 2703.36,
#    'text': ' has become more and more challenging',
#    'tokens': [575, 1813, 544, 293, 544, 7595],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 710,
#    'seek': 268136,
#    'start': 2703.36,
#    'end': 2705.36,
#    'text': ' over the course of this year without question.',
#    'tokens': [670, 264, 1164, 295, 341, 1064, 1553, 1168, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 711,
#    'seek': 268136,
#    'start': 2705.36,
#    'end': 2709.36,
#    'text': ' That means that we have to have policy be more restrictive',
#    'tokens': [663, 1355, 300, 321, 362, 281, 362, 3897, 312, 544, 43220],
#    'temperature': 0.0,
#    'avg_logprob': -0.07232704655877475,
#    'compression_ratio': 1.752895752895753,
#    'no_speech_prob': 0.00016328596393577754},
#   {'id': 712,
#    'seek': 270936,
#    'start': 2709.36,
#    'end': 2712.36,
#    'text': ' and that narrows the path to a soft landing, I would say.',
#    'tokens': [293,
#     300,
#     6397,
#     1509,
#     264,
#     3100,
#     281,
#     257,
#     2787,
#     11202,
#     11,
#     286,
#     576,
#     584,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10811532537142436,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 4.8236106522381306e-05},
#   {'id': 713,
#    'seek': 271236,
#    'start': 2712.36,
#    'end': 2739.36,
#    'text': ' Thanks very much.',
#    'tokens': [50364, 2561, 588, 709, 13, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.2021411316735404,
#    'compression_ratio': 0.68,
#    'no_speech_prob': 0.0006286752177402377}],
#  'language': 'en'}

# %%
output['text']
# Out:
# " Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal. We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses. Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy. Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all. Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate. We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%. In addition, we are continuing the process of significantly reducing the size of our balance sheet. Restoring price stability will likely require maintaining a restrictive stance of policy for some time. I will have more to say about today's monetary policy actions after briefly reviewing economic developments. The U.S. economy has slowed significantly from last year's rapid pace. Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year. Recent indicators point to modest growth of spending and production this quarter. Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions. Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates. Higher interest rates and slower output growth also appear to be weighing on business fixed investment. Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low. Job vacancies still very high and wage growth elevated. Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September. Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers. The labor force participation rate is little changed since the beginning of the year. Inflation remains well above our longer run goal of 2%. Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%. The recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services. Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation. Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters, as well as measures from financial markets. That is not grounds for complacency. The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched. The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people. My colleagues and I are acutely aware that high inflation imposes significant hardship and is at erode's purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation. We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective. At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points, and we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in firming the stance of monetary policy.  ...

# %%
for segment in output['segments']:
  print(segment)
  second = int(segment['start'])
  second = second - (second % 5)
  print(second)
# Out:
# {'id': 0, 'seek': 0, 'start': 0.0, 'end': 8.0, 'text': ' Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal.', 'tokens': [2205, 6499, 13, 1222, 7734, 293, 286, 366, 10613, 7784, 281, 5062, 15860, 646, 760, 281, 527, 568, 4, 3387, 13], 'temperature': 0.0, 'avg_logprob': -0.14512778617240288, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247036159038544}
# 0
# {'id': 1, 'seek': 0, 'start': 8.0, 'end': 16.0, 'text': ' We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses.', 'tokens': [492, 362, 1293, 264, 3873, 300, 321, 643, 293, 264, 14151, 309, 486, 747, 281, 15227, 3218, 11826, 322, 9490, 295, 2665, 4466, 293, 6011, 13], 'temperature': 0.0, 'avg_logprob': -0.14512778617240288, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247036159038544}
# 5
# {'id': 2, 'seek': 0, 'start': 16.0, 'end': 22.0, 'text': ' Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy.', 'tokens': [25803, 11826, 307, 264, 6357, 295, 264, 12380, 26049, 293, 13451, 382, 264, 2901, 17799, 295, 527, 5010, 13], 'temperature': 0.0, 'avg_logprob': -0.14512778617240288, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247036159038544}
# 15
# {'id': 3, 'seek': 2200, 'start': 22.0, 'end': 34.0, 'text': ' Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all.', 'tokens': [9129, 3218, 11826, 11, 264, 5010, 775, 406, 589, 337, 2878, 13, 682, 1729, 11, 1553, 3218, 11826, 11, 321, 486, 406, 4584, 257, 23389, 2896, 295, 2068, 5938, 2142, 4487, 300, 5121, 439, 13], 'temperature': 0.0, 'avg_logprob': -0.06894857743207146, 'compression_ratio': 1.5251141552511416, 'no_speech_prob': 0.0018597592134028673}
# 20
# {'id': 4, 'seek': 2200, 'start': 34.0, 'end': 45.0, 'text': ' Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate.', 'tokens': [2692, 11, 264, 479, 5251, 34, 6005, 527, 3897, 1179, 3314, 538, 9562, 5143, 2793, 293, 321, 2354, 281, 21685, 300, 10452, 8637, 486, 312, 6854, 13], 'temperature': 0.0, 'avg_logprob': -0.06894857743207146, 'compression_ratio': 1.5251141552511416, 'no_speech_prob': 0.0018597592134028673}
# 30
# {'id': 5, 'seek': 4500, 'start': 45.0, 'end': 52.0, 'text': ' We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%.', 'tokens': [492, 366, 2684, 527, 3897, 21033, 4334, 2277, 281, 257, 1496, 300, 486, 312, 31868, 43220, 281, 2736, 15860, 281, 568, 6856], 'temperature': 0.0, 'avg_logprob': -0.03869106629315545, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.0007517836056649685}
# 45
# {'id': 6, 'seek': 4500, 'start': 52.0, 'end': 58.0, 'text': ' In addition, we are continuing the process of significantly reducing the size of our balance sheet.', 'tokens': [682, 4500, 11, 321, 366, 9289, 264, 1399, 295, 10591, 12245, 264, 2744, 295, 527, 4772, 8193, 13], 'temperature': 0.0, 'avg_logprob': -0.03869106629315545, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.0007517836056649685}
# 50
# {'id': 7, 'seek': 4500, 'start': 58.0, 'end': 65.0, 'text': ' Restoring price stability will likely require maintaining a restrictive stance of policy for some time.', 'tokens': [13094, 3662, 3218, 11826, 486, 3700, 3651, 14916, 257, 43220, 21033, 295, 3897, 337, 512, 565, 13], 'temperature': 0.0, 'avg_logprob': -0.03869106629315545, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.0007517836056649685}
# 55
# {'id': 8, 'seek': 4500, 'start': 65.0, 'end': 73.0, 'text': " I will have more to say about today's monetary policy actions after briefly reviewing economic developments.", 'tokens': [286, 486, 362, 544, 281, 584, 466, 965, 311, 26388, 3897, 5909, 934, 10515, 19576, 4836, 20862, 13], 'temperature': 0.0, 'avg_logprob': -0.03869106629315545, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.0007517836056649685}
# 65
# {'id': 9, 'seek': 7300, 'start': 73.0, 'end': 79.0, 'text': " The U.S. economy has slowed significantly from last year's rapid pace.", 'tokens': [440, 624, 13, 50, 13, 5010, 575, 32057, 10591, 490, 1036, 1064, 311, 7558, 11638, 13], 'temperature': 0.0, 'avg_logprob': -0.06411807310013544, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.0005245014326646924}
# 70
# {'id': 10, 'seek': 7300, 'start': 79.0, 'end': 86.0, 'text': ' Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year.', 'tokens': [8467, 19599, 10895, 412, 257, 11638, 295, 568, 13, 21, 4, 1036, 6555, 457, 307, 44553, 370, 1400, 341, 1064, 13], 'temperature': 0.0, 'avg_logprob': -0.06411807310013544, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.0005245014326646924}
# 75
# {'id': 11, 'seek': 7300, 'start': 86.0, 'end': 91.0, 'text': ' Recent indicators point to modest growth of spending and production this quarter.', 'tokens': [17553, 22176, 935, 281, 25403, 4599, 295, 6434, 293, 4265, 341, 6555, 13], 'temperature': 0.0, 'avg_logprob': -0.06411807310013544, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.0005245014326646924}
# 85
# {'id': 12, 'seek': 7300, 'start': 91.0, 'end': 100.0, 'text': " Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions.", 'tokens': [48345, 294, 9711, 6434, 575, 32057, 490, 1036, 1064, 311, 7558, 11638, 294, 644, 23543, 3126, 957, 41578, 5742, 293, 30443, 4669, 4487, 13], 'temperature': 0.0, 'avg_logprob': -0.06411807310013544, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.0005245014326646924}
# 90
# {'id': 13, 'seek': 10000, 'start': 100.0, 'end': 106.0, 'text': ' Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates.', 'tokens': [3251, 4253, 294, 264, 6849, 6977, 575, 42613, 10591, 11, 11611, 23543, 2946, 20236, 6846, 13], 'temperature': 0.0, 'avg_logprob': -0.09521892131903233, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.00042902666609734297}
# 100
# {'id': 14, 'seek': 10000, 'start': 106.0, 'end': 113.0, 'text': ' Higher interest rates and slower output growth also appear to be weighing on business fixed investment.', 'tokens': [31997, 1179, 6846, 293, 14009, 5598, 4599, 611, 4204, 281, 312, 31986, 322, 1606, 6806, 6078, 13], 'temperature': 0.0, 'avg_logprob': -0.09521892131903233, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.00042902666609734297}
# 105
# {'id': 15, 'seek': 10000, 'start': 113.0, 'end': 119.0, 'text': ' Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low.', 'tokens': [11334, 264, 2964, 5093, 294, 4599, 11, 264, 5938, 2142, 7023, 4664, 4524, 365, 264, 17438, 3314, 412, 257, 2625, 12, 5294, 2295, 13], 'temperature': 0.0, 'avg_logprob': -0.09521892131903233, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.00042902666609734297}
# 110
# {'id': 16, 'seek': 10000, 'start': 119.0, 'end': 124.0, 'text': ' Job vacancies still very high and wage growth elevated.', 'tokens': [18602, 2842, 32286, 920, 588, 1090, 293, 15444, 4599, 23457, 13], 'temperature': 0.0, 'avg_logprob': -0.09521892131903233, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.00042902666609734297}
# 115
# {'id': 17, 'seek': 12400, 'start': 124.0, 'end': 133.0, 'text': ' Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September.', 'tokens': [18602, 16823, 362, 668, 13956, 365, 11949, 11636, 538, 364, 4274, 295, 7562, 24, 11, 1360, 4782, 680, 1618, 670, 6897, 293, 7216, 13], 'temperature': 0.0, 'avg_logprob': -0.056701350856471704, 'compression_ratio': 1.5108225108225108, 'no_speech_prob': 0.00013722371659241617}
# 120
# {'id': 18, 'seek': 12400, 'start': 133.0, 'end': 148.0, 'text': ' Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers.', 'tokens': [5780, 1691, 2842, 32286, 362, 4259, 2507, 641, 29687, 293, 264, 11638, 295, 1691, 16823, 575, 32057, 490, 3071, 294, 264, 1064, 11, 264, 5938, 2142, 6515, 281, 312, 484, 295, 4772, 11, 365, 4733, 30797, 14048, 278, 264, 5847, 295, 2435, 5600, 13], 'temperature': 0.0, 'avg_logprob': -0.056701350856471704, 'compression_ratio': 1.5108225108225108, 'no_speech_prob': 0.00013722371659241617}
# 130
# {'id': 19, 'seek': 14800, 'start': 148.0, 'end': 154.0, 'text': ' The labor force participation rate is little changed since the beginning of the year.', 'tokens': [440, 5938, 3464, 13487, 3314, 307, 707, 3105, 1670, 264, 2863, 295, 264, 1064, 13], 'temperature': 0.0, 'avg_logprob': -0.11466116375393337, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.00017902861873153597}
# 145
# {'id': 20, 'seek': 14800, 'start': 154.0, 'end': 158.0, 'text': ' Inflation remains well above our longer run goal of 2%.', 'tokens': [682, 3423, 399, 7023, 731, 3673, 527, 2854, 1190, 3387, 295, 568, 6856], 'temperature': 0.0, 'avg_logprob': -0.11466116375393337, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.00017902861873153597}
# 150
# {'id': 21, 'seek': 14800, 'start': 158.0, 'end': 170.0, 'text': ' Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%.', 'tokens': [4886, 264, 2272, 2493, 8121, 294, 7216, 11, 3217, 6465, 36, 7901, 10895, 412, 1386, 13, 17, 8923, 49999, 264, 34377, 1755, 293, 2281, 10479, 11, 4965, 6465, 36, 7901, 10895, 412, 1025, 13, 16, 6856], 'temperature': 0.0, 'avg_logprob': -0.11466116375393337, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.00017902861873153597}
# 155
# {'id': 22, 'seek': 17000, 'start': 170.0, 'end': 179.0, 'text': ' The recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services.', 'tokens': [440, 5162, 15860, 1412, 797, 362, 808, 294, 2946, 813, 5176, 13, 25803, 23573, 12780, 16371, 2108, 257, 4152, 3613, 295, 10179, 293, 3328, 13], 'temperature': 0.0, 'avg_logprob': -0.09368622303009033, 'compression_ratio': 1.703422053231939, 'no_speech_prob': 0.00014583700976800174}
# 170
# {'id': 23, 'seek': 17000, 'start': 179.0, 'end': 187.0, 'text': " Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation.", 'tokens': [6797, 311, 1516, 1970, 14081, 575, 9194, 292, 7901, 337, 2281, 293, 1755, 293, 575, 2942, 4497, 23452, 3321, 322, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.09368622303009033, 'compression_ratio': 1.703422053231939, 'no_speech_prob': 0.00014583700976800174}
# 175
# {'id': 24, 'seek': 17000, 'start': 187.0, 'end': 198.0, 'text': ' Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters,', 'tokens': [11334, 23457, 15860, 11, 2854, 1433, 15860, 9843, 4204, 281, 6222, 731, 12723, 2769, 11, 382, 15502, 294, 257, 4152, 3613, 295, 22711, 295, 22850, 11, 6011, 11, 293, 2091, 16369, 1559, 11], 'temperature': 0.0, 'avg_logprob': -0.09368622303009033, 'compression_ratio': 1.703422053231939, 'no_speech_prob': 0.00014583700976800174}
# 185
# {'id': 25, 'seek': 19800, 'start': 198.0, 'end': 203.0, 'text': ' as well as measures from financial markets. That is not grounds for complacency.', 'tokens': [382, 731, 382, 8000, 490, 4669, 8383, 13, 663, 307, 406, 19196, 337, 49546, 3020, 13], 'temperature': 0.0, 'avg_logprob': -0.06825909816043478, 'compression_ratio': 1.59375, 'no_speech_prob': 0.0003440464788582176}
# 195
# {'id': 26, 'seek': 19800, 'start': 203.0, 'end': 212.0, 'text': ' The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched.', 'tokens': [440, 2854, 264, 2190, 2372, 295, 1090, 15860, 6515, 11, 264, 5044, 264, 2931, 300, 9843, 295, 2946, 15860, 486, 1813, 948, 42388, 13], 'temperature': 0.0, 'avg_logprob': -0.06825909816043478, 'compression_ratio': 1.59375, 'no_speech_prob': 0.0003440464788582176}
# 200
# {'id': 27, 'seek': 19800, 'start': 212.0, 'end': 220.0, 'text': " The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people.", 'tokens': [440, 7772, 311, 26388, 3897, 5909, 366, 19663, 538, 527, 23885, 281, 9773, 6674, 11949, 293, 8351, 7901, 337, 264, 2665, 561, 13], 'temperature': 0.0, 'avg_logprob': -0.06825909816043478, 'compression_ratio': 1.59375, 'no_speech_prob': 0.0003440464788582176}
# 210
# {'id': 28, 'seek': 22000, 'start': 220.0, 'end': 235.0, 'text': " My colleagues and I are acutely aware that high inflation imposes significant hardship and is at erode's purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation.", 'tokens': [1222, 7734, 293, 286, 366, 696, 325, 736, 3650, 300, 1090, 15860, 704, 4201, 4776, 24172, 293, 307, 412, 1189, 1429, 311, 20906, 1347, 11, 2318, 337, 729, 1935, 1075, 281, 1677, 264, 2946, 5497, 295, 46884, 411, 1755, 11, 6849, 11, 293, 11328, 13], 'temperature': 0.0, 'avg_logprob': -0.08374620920204255, 'compression_ratio': 1.6556016597510372, 'no_speech_prob': 0.00016037006571423262}
# 220
# {'id': 29, 'seek': 22000, 'start': 235.0, 'end': 246.0, 'text': " We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective.", 'tokens': [492, 366, 5405, 43661, 281, 264, 10888, 300, 1090, 15860, 26059, 281, 1293, 4881, 295, 527, 23885, 11, 293, 321, 434, 10613, 7784, 281, 12678, 15860, 281, 527, 568, 4, 10024, 13], 'temperature': 0.0, 'avg_logprob': -0.08374620920204255, 'compression_ratio': 1.6556016597510372, 'no_speech_prob': 0.00016037006571423262}
# 235
# {'id': 30, 'seek': 24600, 'start': 246.0, 'end': 261.0, 'text': " At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points, and we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in firming the stance of monetary policy.", 'tokens': [1711, 965, 311, 3440, 11, 264, 7482, 6005, 264, 3779, 3613, 337, 264, 6019, 8271, 3314, 538, 9562, 5143, 2793, 11, 293, 321, 366, 9289, 264, 1399, 295, 10591, 12245, 264, 2744, 295, 527, 4772, 8193, 11, 597, 5749, 364, 1021, 3090, 294, 12159, 2810, 264, 21033, 295, 26388, 3897, 13], 'temperature': 0.0, 'avg_logprob': -0.12075371619982597, 'compression_ratio': 1.58008658008658, 'no_speech_prob': 0.0003452427336014807}
# 245
# {'id': 31, 'seek': 24600, 'start': 261.0, 'end': 268.0, 'text': " With today's action, we've raised interest rates by 3 and 3-quarters percentage points this year.", 'tokens': [2022, 965, 311, 3069, 11, 321, 600, 6005, 1179, 6846, 538, 805, 293, 805, 12, 17313, 9668, 2793, 341, 1064, 13], 'temperature': 0.0, 'avg_logprob': -0.12075371619982597, 'compression_ratio': 1.58008658008658, 'no_speech_prob': 0.0003452427336014807}
# 260
# {'id': 32, 'seek': 26800, 'start': 268.0, 'end': 281.0, 'text': ' We anticipate that ongoing increases in the target range for the federal funds rate will be appropriate in order to attain a stance of monetary policy that is sufficiently restrictive to return inflation to 2% over time.', 'tokens': [492, 21685, 300, 10452, 8637, 294, 264, 3779, 3613, 337, 264, 6019, 8271, 3314, 486, 312, 6854, 294, 1668, 281, 23766, 257, 21033, 295, 26388, 3897, 300, 307, 31868, 43220, 281, 2736, 15860, 281, 568, 4, 670, 565, 13], 'temperature': 0.0, 'avg_logprob': -0.049927559494972226, 'compression_ratio': 1.6484375, 'no_speech_prob': 9.450737707084045e-05}
# 265
# {'id': 33, 'seek': 26800, 'start': 281.0, 'end': 291.0, 'text': ' Financial conditions have tightened significantly in response to our policy actions, and we are seeing the effects on demand in the most interest rate sensitive sectors of the economy, such as housing.', 'tokens': [25560, 4487, 362, 49673, 10591, 294, 4134, 281, 527, 3897, 5909, 11, 293, 321, 366, 2577, 264, 5065, 322, 4733, 294, 264, 881, 1179, 3314, 9477, 18373, 295, 264, 5010, 11, 1270, 382, 6849, 13], 'temperature': 0.0, 'avg_logprob': -0.049927559494972226, 'compression_ratio': 1.6484375, 'no_speech_prob': 9.450737707084045e-05}
# 280
# {'id': 34, 'seek': 29100, 'start': 291.0, 'end': 298.0, 'text': ' It will take time, however, for the full effects of monetary restraint to be realized, especially on inflation.', 'tokens': [467, 486, 747, 565, 11, 4461, 11, 337, 264, 1577, 5065, 295, 26388, 49281, 281, 312, 5334, 11, 2318, 322, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.04512661856573981, 'compression_ratio': 1.6727272727272726, 'no_speech_prob': 0.0002903198474086821}
# 290
# {'id': 35, 'seek': 29100, 'start': 298.0, 'end': 312.0, 'text': " That's why we say in our statement that in determining the pace of future increases in the target range, we will take into account the cumulative tightening of monetary policy and the lags with which monetary policy affects economic activity and inflation.", 'tokens': [663, 311, 983, 321, 584, 294, 527, 5629, 300, 294, 23751, 264, 11638, 295, 2027, 8637, 294, 264, 3779, 3613, 11, 321, 486, 747, 666, 2696, 264, 38379, 42217, 295, 26388, 3897, 293, 264, 8953, 82, 365, 597, 26388, 3897, 11807, 4836, 5191, 293, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.04512661856573981, 'compression_ratio': 1.6727272727272726, 'no_speech_prob': 0.0002903198474086821}
# 295
# {'id': 36, 'seek': 31200, 'start': 312.0, 'end': 325.0, 'text': " At some point, as I've said in the last two press conferences, it will become appropriate to slow the pace of increases, as we approach the level of interest rates that will be sufficiently restrictive to bring inflation down to our 2% goal.", 'tokens': [1711, 512, 935, 11, 382, 286, 600, 848, 294, 264, 1036, 732, 1886, 22032, 11, 309, 486, 1813, 6854, 281, 2964, 264, 11638, 295, 8637, 11, 382, 321, 3109, 264, 1496, 295, 1179, 6846, 300, 486, 312, 31868, 43220, 281, 1565, 15860, 760, 281, 527, 568, 4, 3387, 13], 'temperature': 0.0, 'avg_logprob': -0.047421115817445694, 'compression_ratio': 1.6030927835051547, 'no_speech_prob': 7.463931251550093e-05}
# 310
# {'id': 37, 'seek': 31200, 'start': 325.0, 'end': 330.0, 'text': ' There is significant uncertainty around that level of interest rates.', 'tokens': [821, 307, 4776, 15697, 926, 300, 1496, 295, 1179, 6846, 13], 'temperature': 0.0, 'avg_logprob': -0.047421115817445694, 'compression_ratio': 1.6030927835051547, 'no_speech_prob': 7.463931251550093e-05}
# 325
# {'id': 38, 'seek': 33000, 'start': 330.0, 'end': 342.0, 'text': ' Even so, we still have some ways to go, and incoming data since our last meeting suggests that the ultimate level of interest rates will be higher than previously expected.', 'tokens': [2754, 370, 11, 321, 920, 362, 512, 2098, 281, 352, 11, 293, 22341, 1412, 1670, 527, 1036, 3440, 13409, 300, 264, 9705, 1496, 295, 1179, 6846, 486, 312, 2946, 813, 8046, 5176, 13], 'temperature': 0.0, 'avg_logprob': -0.06100991835077125, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.00010856004519155249}
# 330
# {'id': 39, 'seek': 33000, 'start': 342.0, 'end': 349.0, 'text': ' Our decisions will depend on the totality of incoming data and their implications for the outlook for economic activity and inflation.', 'tokens': [2621, 5327, 486, 5672, 322, 264, 1993, 1860, 295, 22341, 1412, 293, 641, 16602, 337, 264, 26650, 337, 4836, 5191, 293, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.06100991835077125, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.00010856004519155249}
# 340
# {'id': 40, 'seek': 33000, 'start': 349.0, 'end': 355.0, 'text': ' We will continue to make our decisions meeting by being and communicate our thinking as clearly as possible.', 'tokens': [492, 486, 2354, 281, 652, 527, 5327, 3440, 538, 885, 293, 7890, 527, 1953, 382, 4448, 382, 1944, 13], 'temperature': 0.0, 'avg_logprob': -0.06100991835077125, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.00010856004519155249}
# 345
# {'id': 41, 'seek': 35500, 'start': 355.0, 'end': 360.0, 'text': " We're taking forceful steps to moderate demand so that it comes into better alignment with supply.", 'tokens': [492, 434, 1940, 3464, 906, 4439, 281, 18174, 4733, 370, 300, 309, 1487, 666, 1101, 18515, 365, 5847, 13], 'temperature': 0.0, 'avg_logprob': -0.05166846890992756, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.0001734936231514439}
# 355
# {'id': 42, 'seek': 35500, 'start': 360.0, 'end': 370.0, 'text': ' Our overarching focus is using our tools to bring inflation back down to our 2% goal and to keep longer term inflation expectations well anchored.', 'tokens': [2621, 45501, 1879, 307, 1228, 527, 3873, 281, 1565, 15860, 646, 760, 281, 527, 568, 4, 3387, 293, 281, 1066, 2854, 1433, 15860, 9843, 731, 12723, 2769, 13], 'temperature': 0.0, 'avg_logprob': -0.05166846890992756, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.0001734936231514439}
# 360
# {'id': 43, 'seek': 35500, 'start': 370.0, 'end': 379.0, 'text': ' Reducing inflation is likely to require a sustained period of below trend growth and some softening of labor market conditions.', 'tokens': [4477, 1311, 278, 15860, 307, 3700, 281, 3651, 257, 23389, 2896, 295, 2507, 6028, 4599, 293, 512, 2787, 4559, 295, 5938, 2142, 4487, 13], 'temperature': 0.0, 'avg_logprob': -0.05166846890992756, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.0001734936231514439}
# 370
# {'id': 44, 'seek': 37900, 'start': 379.0, 'end': 386.0, 'text': ' Restoring price stability is essential to set the stage for achieving maximum employment and stable prices in the longer run.', 'tokens': [13094, 3662, 3218, 11826, 307, 7115, 281, 992, 264, 3233, 337, 19626, 6674, 11949, 293, 8351, 7901, 294, 264, 2854, 1190, 13], 'temperature': 0.0, 'avg_logprob': -0.051298302273417626, 'compression_ratio': 1.5992217898832686, 'no_speech_prob': 0.0003394588129594922}
# 375
# {'id': 45, 'seek': 37900, 'start': 386.0, 'end': 391.0, 'text': ' The historical record caution strongly against prematurely loosening policy.', 'tokens': [440, 8584, 2136, 23585, 10613, 1970, 34877, 356, 40454, 4559, 3897, 13], 'temperature': 0.0, 'avg_logprob': -0.051298302273417626, 'compression_ratio': 1.5992217898832686, 'no_speech_prob': 0.0003394588129594922}
# 385
# {'id': 46, 'seek': 37900, 'start': 391.0, 'end': 394.0, 'text': ' We will stay the course until the job is done.', 'tokens': [492, 486, 1754, 264, 1164, 1826, 264, 1691, 307, 1096, 13], 'temperature': 0.0, 'avg_logprob': -0.051298302273417626, 'compression_ratio': 1.5992217898832686, 'no_speech_prob': 0.0003394588129594922}
# 390
# {'id': 47, 'seek': 37900, 'start': 394.0, 'end': 400.0, 'text': ' To conclude, we understand that our actions affect communities, families and businesses across the country.', 'tokens': [1407, 16886, 11, 321, 1223, 300, 527, 5909, 3345, 4456, 11, 4466, 293, 6011, 2108, 264, 1941, 13], 'temperature': 0.0, 'avg_logprob': -0.051298302273417626, 'compression_ratio': 1.5992217898832686, 'no_speech_prob': 0.0003394588129594922}
# 390
# {'id': 48, 'seek': 37900, 'start': 400.0, 'end': 404.0, 'text': ' Everything we do is in service to our public mission.', 'tokens': [5471, 321, 360, 307, 294, 2643, 281, 527, 1908, 4447, 13], 'temperature': 0.0, 'avg_logprob': -0.051298302273417626, 'compression_ratio': 1.5992217898832686, 'no_speech_prob': 0.0003394588129594922}
# 400
# {'id': 49, 'seek': 40400, 'start': 404.0, 'end': 410.0, 'text': ' We at the Fed will do everything we can to achieve our maximum employment and price stability goals.', 'tokens': [492, 412, 264, 7772, 486, 360, 1203, 321, 393, 281, 4584, 527, 6674, 11949, 293, 3218, 11826, 5493, 13], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 400
# {'id': 50, 'seek': 40400, 'start': 410.0, 'end': 413.0, 'text': ' Thank you and I look forward to your questions.', 'tokens': [1044, 291, 293, 286, 574, 2128, 281, 428, 1651, 13], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 410
# {'id': 51, 'seek': 40400, 'start': 413.0, 'end': 417.0, 'text': ' Thank you, Colby.', 'tokens': [1044, 291, 11, 4004, 2322, 13], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 410
# {'id': 52, 'seek': 40400, 'start': 417.0, 'end': 420.0, 'text': ' Thank you. Colby Smith with the Financial Times.', 'tokens': [1044, 291, 13, 4004, 2322, 8538, 365, 264, 25560, 11366, 13], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 415
# {'id': 53, 'seek': 40400, 'start': 420.0, 'end': 423.0, 'text': ' On the need to slow the pace of rate increases at some point.', 'tokens': [1282, 264, 643, 281, 2964, 264, 11638, 295, 3314, 8637, 412, 512, 935, 13], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 420
# {'id': 54, 'seek': 40400, 'start': 423.0, 'end': 431.0, 'text': " Is a is a downshift contingent on a string of better inflation data specifically between now and let's say the December meeting?", 'tokens': [1119, 257, 307, 257, 760, 47445, 27820, 317, 322, 257, 6798, 295, 1101, 15860, 1412, 4682, 1296, 586, 293, 718, 311, 584, 264, 7687, 3440, 30], 'temperature': 0.0, 'avg_logprob': -0.11557177543640136, 'compression_ratio': 1.573643410852713, 'no_speech_prob': 0.000559836276806891}
# 420
# {'id': 55, 'seek': 43100, 'start': 431.0, 'end': 439.0, 'text': ' Is that something that the Fed could potentially proceed with independent of that data given the lag defects that you mentioned?', 'tokens': [1119, 300, 746, 300, 264, 7772, 727, 7263, 8991, 365, 6695, 295, 300, 1412, 2212, 264, 8953, 32655, 300, 291, 2835, 30], 'temperature': 0.0, 'avg_logprob': -0.10891240781491941, 'compression_ratio': 1.745644599303136, 'no_speech_prob': 0.0004565146518871188}
# 430
# {'id': 56, 'seek': 43100, 'start': 439.0, 'end': 442.0, 'text': ' So a couple of things on that.', 'tokens': [407, 257, 1916, 295, 721, 322, 300, 13], 'temperature': 0.0, 'avg_logprob': -0.10891240781491941, 'compression_ratio': 1.745644599303136, 'no_speech_prob': 0.0004565146518871188}
# 435
# {'id': 57, 'seek': 43100, 'start': 442.0, 'end': 449.0, 'text': ' We do need to see inflation coming down decisively and good at evidence of that would be a series of down monthly readings.', 'tokens': [492, 360, 643, 281, 536, 15860, 1348, 760, 18206, 3413, 293, 665, 412, 4467, 295, 300, 576, 312, 257, 2638, 295, 760, 12878, 27319, 13], 'temperature': 0.0, 'avg_logprob': -0.10891240781491941, 'compression_ratio': 1.745644599303136, 'no_speech_prob': 0.0004565146518871188}
# 440
# {'id': 58, 'seek': 43100, 'start': 449.0, 'end': 451.0, 'text': " Of course that's what we'd all love to see.", 'tokens': [2720, 1164, 300, 311, 437, 321, 1116, 439, 959, 281, 536, 13], 'temperature': 0.0, 'avg_logprob': -0.10891240781491941, 'compression_ratio': 1.745644599303136, 'no_speech_prob': 0.0004565146518871188}
# 445
# {'id': 59, 'seek': 43100, 'start': 451.0, 'end': 460.0, 'text': " But that's I've never thought of that as the appropriate test for slowing the pace of increases or for identifying the appropriately restrictive level that we're aiming for.", 'tokens': [583, 300, 311, 286, 600, 1128, 1194, 295, 300, 382, 264, 6854, 1500, 337, 26958, 264, 11638, 295, 8637, 420, 337, 16696, 264, 23505, 43220, 1496, 300, 321, 434, 20253, 337, 13], 'temperature': 0.0, 'avg_logprob': -0.10891240781491941, 'compression_ratio': 1.745644599303136, 'no_speech_prob': 0.0004565146518871188}
# 450
# {'id': 60, 'seek': 46000, 'start': 460.0, 'end': 468.0, 'text': " We need to bring our policy stance down to a level that's sufficiently restrictive to bring inflation down to our 2% objective over the medium term.", 'tokens': [492, 643, 281, 1565, 527, 3897, 21033, 760, 281, 257, 1496, 300, 311, 31868, 43220, 281, 1565, 15860, 760, 281, 527, 568, 4, 10024, 670, 264, 6399, 1433, 13], 'temperature': 0.0, 'avg_logprob': -0.08687067914892126, 'compression_ratio': 1.6711409395973154, 'no_speech_prob': 0.00026084622368216515}
# 460
# {'id': 61, 'seek': 46000, 'start': 468.0, 'end': 470.0, 'text': " How will we know that we've reached that level?", 'tokens': [1012, 486, 321, 458, 300, 321, 600, 6488, 300, 1496, 30], 'temperature': 0.0, 'avg_logprob': -0.08687067914892126, 'compression_ratio': 1.6711409395973154, 'no_speech_prob': 0.00026084622368216515}
# 465
# {'id': 62, 'seek': 46000, 'start': 470.0, 'end': 478.0, 'text': " Well, we'll take into account the full range of analysis and data that bear on that question guided by our assessment of how much financial conditions have tightened.", 'tokens': [1042, 11, 321, 603, 747, 666, 2696, 264, 1577, 3613, 295, 5215, 293, 1412, 300, 6155, 322, 300, 1168, 19663, 538, 527, 9687, 295, 577, 709, 4669, 4487, 362, 49673, 13], 'temperature': 0.0, 'avg_logprob': -0.08687067914892126, 'compression_ratio': 1.6711409395973154, 'no_speech_prob': 0.00026084622368216515}
# 470
# {'id': 63, 'seek': 46000, 'start': 478.0, 'end': 483.0, 'text': ' The effects of that tightening is actually having on the real economy and on inflation.', 'tokens': [440, 5065, 295, 300, 42217, 307, 767, 1419, 322, 264, 957, 5010, 293, 322, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.08687067914892126, 'compression_ratio': 1.6711409395973154, 'no_speech_prob': 0.00026084622368216515}
# 475
# {'id': 64, 'seek': 46000, 'start': 483.0, 'end': 486.0, 'text': ' Taking into consideration lags as I mentioned.', 'tokens': [17837, 666, 12381, 8953, 82, 382, 286, 2835, 13], 'temperature': 0.0, 'avg_logprob': -0.08687067914892126, 'compression_ratio': 1.6711409395973154, 'no_speech_prob': 0.00026084622368216515}
# 480
# {'id': 65, 'seek': 48600, 'start': 486.0, 'end': 493.0, 'text': ' We will be looking at real rates, for example, all across the yield curve and all other financial conditions.', 'tokens': [492, 486, 312, 1237, 412, 957, 6846, 11, 337, 1365, 11, 439, 2108, 264, 11257, 7605, 293, 439, 661, 4669, 4487, 13], 'temperature': 0.0, 'avg_logprob': -0.18498695775082236, 'compression_ratio': 1.565040650406504, 'no_speech_prob': 0.00046514946734532714}
# 485
# {'id': 66, 'seek': 48600, 'start': 493.0, 'end': 496.0, 'text': ' And as we make that assessment.', 'tokens': [400, 382, 321, 652, 300, 9687, 13], 'temperature': 0.0, 'avg_logprob': -0.18498695775082236, 'compression_ratio': 1.565040650406504, 'no_speech_prob': 0.00046514946734532714}
# 490
# {'id': 67, 'seek': 48600, 'start': 496.0, 'end': 502.0, 'text': ' I wish neither with with rotors.', 'tokens': [286, 3172, 9662, 365, 365, 4297, 830, 13], 'temperature': 0.0, 'avg_logprob': -0.18498695775082236, 'compression_ratio': 1.565040650406504, 'no_speech_prob': 0.00046514946734532714}
# 495
# {'id': 68, 'seek': 48600, 'start': 502.0, 'end': 508.0, 'text': " Look, I'm sure there's going to be tons of confusion out there about whether this means you're going to slow in December or not.", 'tokens': [2053, 11, 286, 478, 988, 456, 311, 516, 281, 312, 9131, 295, 15075, 484, 456, 466, 1968, 341, 1355, 291, 434, 516, 281, 2964, 294, 7687, 420, 406, 13], 'temperature': 0.0, 'avg_logprob': -0.18498695775082236, 'compression_ratio': 1.565040650406504, 'no_speech_prob': 0.00046514946734532714}
# 500
# {'id': 69, 'seek': 48600, 'start': 508.0, 'end': 513.0, 'text': ' Would you say that the bias right now is not for another 75 basis point increase?', 'tokens': [6068, 291, 584, 300, 264, 12577, 558, 586, 307, 406, 337, 1071, 9562, 5143, 935, 3488, 30], 'temperature': 0.0, 'avg_logprob': -0.18498695775082236, 'compression_ratio': 1.565040650406504, 'no_speech_prob': 0.00046514946734532714}
# 505
# {'id': 70, 'seek': 51300, 'start': 513.0, 'end': 523.0, 'text': ' So what I want to do is put that question of pace in the context of our broader tightening program of fine-day.', 'tokens': [407, 437, 286, 528, 281, 360, 307, 829, 300, 1168, 295, 11638, 294, 264, 4319, 295, 527, 13227, 42217, 1461, 295, 2489, 12, 810, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 510
# {'id': 71, 'seek': 51300, 'start': 523.0, 'end': 526.0, 'text': ' And to talk about the statement language along the way.', 'tokens': [400, 281, 751, 466, 264, 5629, 2856, 2051, 264, 636, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 520
# {'id': 72, 'seek': 51300, 'start': 526.0, 'end': 531.0, 'text': ' So I think you can think about our tightening program as really addressing three questions.', 'tokens': [407, 286, 519, 291, 393, 519, 466, 527, 42217, 1461, 382, 534, 14329, 1045, 1651, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 525
# {'id': 73, 'seek': 51300, 'start': 531.0, 'end': 534.0, 'text': ' The first of which was and has been how fast to go.', 'tokens': [440, 700, 295, 597, 390, 293, 575, 668, 577, 2370, 281, 352, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 530
# {'id': 74, 'seek': 51300, 'start': 534.0, 'end': 537.0, 'text': ' The second is how high to raise our policy rate.', 'tokens': [440, 1150, 307, 577, 1090, 281, 5300, 527, 3897, 3314, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 530
# {'id': 75, 'seek': 51300, 'start': 537.0, 'end': 542.0, 'text': ' And the third will be eventually how long to remain at a restrictive level.', 'tokens': [400, 264, 2636, 486, 312, 4728, 577, 938, 281, 6222, 412, 257, 43220, 1496, 13], 'temperature': 0.0, 'avg_logprob': -0.14250679016113282, 'compression_ratio': 1.6964980544747081, 'no_speech_prob': 0.0003001739678438753}
# 535
# {'id': 76, 'seek': 54200, 'start': 542.0, 'end': 546.0, 'text': ' On the first question, how fast to tighten policy.', 'tokens': [1282, 264, 700, 1168, 11, 577, 2370, 281, 17041, 3897, 13], 'temperature': 0.0, 'avg_logprob': -0.09875867051898309, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.00014638992433901876}
# 540
# {'id': 77, 'seek': 54200, 'start': 546.0, 'end': 550.0, 'text': " It's been very important that we move expeditiously and we have clearly done so.", 'tokens': [467, 311, 668, 588, 1021, 300, 321, 1286, 19348, 270, 8994, 293, 321, 362, 4448, 1096, 370, 13], 'temperature': 0.0, 'avg_logprob': -0.09875867051898309, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.00014638992433901876}
# 545
# {'id': 78, 'seek': 54200, 'start': 550.0, 'end': 555.0, 'text': " We've moved three and three quarters percent since March, admittedly from a base of zero.", 'tokens': [492, 600, 4259, 1045, 293, 1045, 20612, 3043, 1670, 6129, 11, 14920, 356, 490, 257, 3096, 295, 4018, 13], 'temperature': 0.0, 'avg_logprob': -0.09875867051898309, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.00014638992433901876}
# 550
# {'id': 79, 'seek': 54200, 'start': 555.0, 'end': 564.0, 'text': " It's a historically fast pace and that's certainly appropriate given the persistence and strength and inflation and the low level from which we started.", 'tokens': [467, 311, 257, 16180, 2370, 11638, 293, 300, 311, 3297, 6854, 2212, 264, 37617, 293, 3800, 293, 15860, 293, 264, 2295, 1496, 490, 597, 321, 1409, 13], 'temperature': 0.0, 'avg_logprob': -0.09875867051898309, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.00014638992433901876}
# 555
# {'id': 80, 'seek': 54200, 'start': 564.0, 'end': 568.0, 'text': ' So now we come to the second question, which is how high to raise our policy rate.', 'tokens': [407, 586, 321, 808, 281, 264, 1150, 1168, 11, 597, 307, 577, 1090, 281, 5300, 527, 3897, 3314, 13], 'temperature': 0.0, 'avg_logprob': -0.09875867051898309, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.00014638992433901876}
# 560
# {'id': 81, 'seek': 56800, 'start': 568.0, 'end': 575.0, 'text': " And we're saying that we'd raise that rate to a level that's sufficiently restrictive to bring inflation to our 2% target over time.", 'tokens': [400, 321, 434, 1566, 300, 321, 1116, 5300, 300, 3314, 281, 257, 1496, 300, 311, 31868, 43220, 281, 1565, 15860, 281, 527, 568, 4, 3779, 670, 565, 13], 'temperature': 0.0, 'avg_logprob': -0.10927804311116536, 'compression_ratio': 1.6641221374045803, 'no_speech_prob': 0.0004232008068356663}
# 565
# {'id': 82, 'seek': 56800, 'start': 575.0, 'end': 582.0, 'text': ' And we put that into our post-meeting statement because that really does become the important question we think now.', 'tokens': [400, 321, 829, 300, 666, 527, 2183, 12, 1398, 9880, 5629, 570, 300, 534, 775, 1813, 264, 1021, 1168, 321, 519, 586, 13], 'temperature': 0.0, 'avg_logprob': -0.10927804311116536, 'compression_ratio': 1.6641221374045803, 'no_speech_prob': 0.0004232008068356663}
# 575
# {'id': 83, 'seek': 56800, 'start': 582.0, 'end': 586.0, 'text': " Is how far to go and I'll talk more about that.", 'tokens': [1119, 577, 1400, 281, 352, 293, 286, 603, 751, 544, 466, 300, 13], 'temperature': 0.0, 'avg_logprob': -0.10927804311116536, 'compression_ratio': 1.6641221374045803, 'no_speech_prob': 0.0004232008068356663}
# 580
# {'id': 84, 'seek': 56800, 'start': 586.0, 'end': 588.0, 'text': " We think there's some ground to cover.", 'tokens': [492, 519, 456, 311, 512, 2727, 281, 2060, 13], 'temperature': 0.0, 'avg_logprob': -0.10927804311116536, 'compression_ratio': 1.6641221374045803, 'no_speech_prob': 0.0004232008068356663}
# 585
# {'id': 85, 'seek': 56800, 'start': 588.0, 'end': 593.0, 'text': " But before we meet that test and that's why we say that ongoing rate increases will be appropriate.", 'tokens': [583, 949, 321, 1677, 300, 1500, 293, 300, 311, 983, 321, 584, 300, 10452, 3314, 8637, 486, 312, 6854, 13], 'temperature': 0.0, 'avg_logprob': -0.10927804311116536, 'compression_ratio': 1.6641221374045803, 'no_speech_prob': 0.0004232008068356663}
# 585
# {'id': 86, 'seek': 59300, 'start': 593.0, 'end': 607.0, 'text': ' And as I mentioned, incoming data between the meetings, both the strong Labor Market Report, but particularly the CPI report, do suggest to me that we may ultimately move to higher levels than we thought at the time of the September meeting.', 'tokens': [400, 382, 286, 2835, 11, 22341, 1412, 1296, 264, 8410, 11, 1293, 264, 2068, 17250, 15596, 16057, 11, 457, 4098, 264, 22431, 40, 2275, 11, 360, 3402, 281, 385, 300, 321, 815, 6284, 1286, 281, 2946, 4358, 813, 321, 1194, 412, 264, 565, 295, 264, 7216, 3440, 13], 'temperature': 0.0, 'avg_logprob': -0.10253508718390214, 'compression_ratio': 1.6091954022988506, 'no_speech_prob': 0.00030925575993023813}
# 590
# {'id': 87, 'seek': 59300, 'start': 607.0, 'end': 614.0, 'text': " That level is very uncertain though and I would say we're going to find it over time.", 'tokens': [663, 1496, 307, 588, 11308, 1673, 293, 286, 576, 584, 321, 434, 516, 281, 915, 309, 670, 565, 13], 'temperature': 0.0, 'avg_logprob': -0.10253508718390214, 'compression_ratio': 1.6091954022988506, 'no_speech_prob': 0.00030925575993023813}
# 605
# {'id': 88, 'seek': 59300, 'start': 614.0, 'end': 620.0, 'text': " Of course, with the lags between policy and economic activity, there's a lot of uncertainty.", 'tokens': [2720, 1164, 11, 365, 264, 8953, 82, 1296, 3897, 293, 4836, 5191, 11, 456, 311, 257, 688, 295, 15697, 13], 'temperature': 0.0, 'avg_logprob': -0.10253508718390214, 'compression_ratio': 1.6091954022988506, 'no_speech_prob': 0.00030925575993023813}
# 610
# {'id': 89, 'seek': 62000, 'start': 620.0, 'end': 631.0, 'text': ' So we note that in determining the pace of future increases will take into account the cumulative tightening of monetary policy as well as the lags with monetary policy affects economic activity inflation.', 'tokens': [407, 321, 3637, 300, 294, 23751, 264, 11638, 295, 2027, 8637, 486, 747, 666, 2696, 264, 38379, 42217, 295, 26388, 3897, 382, 731, 382, 264, 8953, 82, 365, 26388, 3897, 11807, 4836, 5191, 15860, 13], 'temperature': 0.0, 'avg_logprob': -0.08001947857084729, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.0003003074089065194}
# 620
# {'id': 90, 'seek': 62000, 'start': 631.0, 'end': 636.0, 'text': ' So I would say as we come closer to that level, move more into restrictive territory.', 'tokens': [407, 286, 576, 584, 382, 321, 808, 4966, 281, 300, 1496, 11, 1286, 544, 666, 43220, 11360, 13], 'temperature': 0.0, 'avg_logprob': -0.08001947857084729, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.0003003074089065194}
# 630
# {'id': 91, 'seek': 62000, 'start': 636.0, 'end': 640.0, 'text': ' The question of speed becomes less important than the second and third questions.', 'tokens': [440, 1168, 295, 3073, 3643, 1570, 1021, 813, 264, 1150, 293, 2636, 1651, 13], 'temperature': 0.0, 'avg_logprob': -0.08001947857084729, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.0003003074089065194}
# 635
# {'id': 92, 'seek': 62000, 'start': 640.0, 'end': 647.0, 'text': " And that's why I've said it the last two press conferences that at some point it will become appropriate to slow the pace of increases.", 'tokens': [400, 300, 311, 983, 286, 600, 848, 309, 264, 1036, 732, 1886, 22032, 300, 412, 512, 935, 309, 486, 1813, 6854, 281, 2964, 264, 11638, 295, 8637, 13], 'temperature': 0.0, 'avg_logprob': -0.08001947857084729, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.0003003074089065194}
# 640
# {'id': 93, 'seek': 64700, 'start': 647.0, 'end': 652.0, 'text': ' So that time is coming and it may come as soon as the next meeting or the one after that.', 'tokens': [407, 300, 565, 307, 1348, 293, 309, 815, 808, 382, 2321, 382, 264, 958, 3440, 420, 264, 472, 934, 300, 13], 'temperature': 0.0, 'avg_logprob': -0.061083898090180895, 'compression_ratio': 1.7099236641221374, 'no_speech_prob': 0.0001374382700305432}
# 645
# {'id': 94, 'seek': 64700, 'start': 652.0, 'end': 654.0, 'text': ' No decision has been made.', 'tokens': [883, 3537, 575, 668, 1027, 13], 'temperature': 0.0, 'avg_logprob': -0.061083898090180895, 'compression_ratio': 1.7099236641221374, 'no_speech_prob': 0.0001374382700305432}
# 650
# {'id': 95, 'seek': 64700, 'start': 654.0, 'end': 660.0, 'text': " It is likely we'll have a discussion about this at the next meeting, a discussion.", 'tokens': [467, 307, 3700, 321, 603, 362, 257, 5017, 466, 341, 412, 264, 958, 3440, 11, 257, 5017, 13], 'temperature': 0.0, 'avg_logprob': -0.061083898090180895, 'compression_ratio': 1.7099236641221374, 'no_speech_prob': 0.0001374382700305432}
# 650
# {'id': 96, 'seek': 64700, 'start': 660.0, 'end': 676.0, 'text': ' To be clear, let me say again, the question of when to moderate the pace of increases is now much less important than the question of how high to raise rates and how long to keep monetary policy restricted, which really will be our principal focus.', 'tokens': [1407, 312, 1850, 11, 718, 385, 584, 797, 11, 264, 1168, 295, 562, 281, 18174, 264, 11638, 295, 8637, 307, 586, 709, 1570, 1021, 813, 264, 1168, 295, 577, 1090, 281, 5300, 6846, 293, 577, 938, 281, 1066, 26388, 3897, 20608, 11, 597, 534, 486, 312, 527, 9716, 1879, 13], 'temperature': 0.0, 'avg_logprob': -0.061083898090180895, 'compression_ratio': 1.7099236641221374, 'no_speech_prob': 0.0001374382700305432}
# 660
# {'id': 97, 'seek': 67600, 'start': 676.0, 'end': 678.0, 'text': ' So I think I could follow up on that.', 'tokens': [407, 286, 519, 286, 727, 1524, 493, 322, 300, 13], 'temperature': 0.0, 'avg_logprob': -0.17812301929180438, 'compression_ratio': 1.489795918367347, 'no_speech_prob': 0.00041542999679222703}
# 675
# {'id': 98, 'seek': 67600, 'start': 678.0, 'end': 696.0, 'text': ' To what degree was there an importance or weight given to a need to signal this possibility now given all the concerns really around the globe about fed policy sort of driving ahead and everybody else, you know, dealing with their own stress as a result.', 'tokens': [1407, 437, 4314, 390, 456, 364, 7379, 420, 3364, 2212, 281, 257, 643, 281, 6358, 341, 7959, 586, 2212, 439, 264, 7389, 534, 926, 264, 15371, 466, 4636, 3897, 1333, 295, 4840, 2286, 293, 2201, 1646, 11, 291, 458, 11, 6260, 365, 641, 1065, 4244, 382, 257, 1874, 13], 'temperature': 0.0, 'avg_logprob': -0.17812301929180438, 'compression_ratio': 1.489795918367347, 'no_speech_prob': 0.00041542999679222703}
# 675
# {'id': 99, 'seek': 69600, 'start': 696.0, 'end': 712.0, 'text': " I think I'm pleased that we have moved as fast as we have. I don't think we've over tightened. I think there's very difficult to make a case that our current level is too tight given that inflation still runs well above the federal funds rate.", 'tokens': [286, 519, 286, 478, 10587, 300, 321, 362, 4259, 382, 2370, 382, 321, 362, 13, 286, 500, 380, 519, 321, 600, 670, 49673, 13, 286, 519, 456, 311, 588, 2252, 281, 652, 257, 1389, 300, 527, 2190, 1496, 307, 886, 4524, 2212, 300, 15860, 920, 6676, 731, 3673, 264, 6019, 8271, 3314, 13], 'temperature': 0.0, 'avg_logprob': -0.08305399877983227, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.00026922067627310753}
# 695
# {'id': 100, 'seek': 71200, 'start': 712.0, 'end': 724.0, 'text': " So I think that at this meeting, I've the last two meetings, as I've mentioned, I've said that we that there would come a point and this was a meeting at which we had a discussion about what that might mean.", 'tokens': [407, 286, 519, 300, 412, 341, 3440, 11, 286, 600, 264, 1036, 732, 8410, 11, 382, 286, 600, 2835, 11, 286, 600, 848, 300, 321, 300, 456, 576, 808, 257, 935, 293, 341, 390, 257, 3440, 412, 597, 321, 632, 257, 5017, 466, 437, 300, 1062, 914, 13], 'temperature': 0.0, 'avg_logprob': -0.15154604660837273, 'compression_ratio': 1.7096774193548387, 'no_speech_prob': 0.0003401062567718327}
# 710
# {'id': 101, 'seek': 71200, 'start': 724.0, 'end': 729.0, 'text': " And we did discuss this and as I mentioned, we'll discuss it again in December.", 'tokens': [400, 321, 630, 2248, 341, 293, 382, 286, 2835, 11, 321, 603, 2248, 309, 797, 294, 7687, 13], 'temperature': 0.0, 'avg_logprob': -0.15154604660837273, 'compression_ratio': 1.7096774193548387, 'no_speech_prob': 0.0003401062567718327}
# 720
# {'id': 102, 'seek': 71200, 'start': 729.0, 'end': 733.0, 'text': " But there's no, I don't have any sense that we've over tightened or moved too fast.", 'tokens': [583, 456, 311, 572, 11, 286, 500, 380, 362, 604, 2020, 300, 321, 600, 670, 49673, 420, 4259, 886, 2370, 13], 'temperature': 0.0, 'avg_logprob': -0.15154604660837273, 'compression_ratio': 1.7096774193548387, 'no_speech_prob': 0.0003401062567718327}
# 725
# {'id': 103, 'seek': 73300, 'start': 733.0, 'end': 744.0, 'text': " I think it's been good in a successful program. We we that we've gotten this far this fast. Remember that that we still think there's a need for ongoing rate increases.", 'tokens': [286, 519, 309, 311, 668, 665, 294, 257, 4406, 1461, 13, 492, 321, 300, 321, 600, 5768, 341, 1400, 341, 2370, 13, 5459, 300, 300, 321, 920, 519, 456, 311, 257, 643, 337, 10452, 3314, 8637, 13], 'temperature': 0.0, 'avg_logprob': -0.22534208782648635, 'compression_ratio': 1.5, 'no_speech_prob': 0.00035115660284645855}
# 730
# ...
# 2555
# {'id': 666, 'seek': 253908, 'start': 2564.96, 'end': 2566.4, 'text': " Do you still think it's possible?", 'tokens': [1144, 291, 920, 519, 309, 311, 1944, 30], 'temperature': 0.0, 'avg_logprob': -0.2853878746347979, 'compression_ratio': 1.5426356589147288, 'no_speech_prob': 0.00021298664796631783}
# 2560
# {'id': 667, 'seek': 256640, 'start': 2566.4, 'end': 2570.64, 'text': ' Has the narrowed, yes, is it still possible?', 'tokens': [8646, 264, 9432, 292, 11, 2086, 11, 307, 309, 920, 1944, 30], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2565
# {'id': 668, 'seek': 256640, 'start': 2570.64, 'end': 2571.64, 'text': ' Yes.', 'tokens': [1079, 13], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2570
# {'id': 669, 'seek': 256640, 'start': 2571.64, 'end': 2574.6800000000003, 'text': " I think we've always said it was gonna be difficult,", 'tokens': [286, 519, 321, 600, 1009, 848, 309, 390, 799, 312, 2252, 11], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2570
# {'id': 670, 'seek': 256640, 'start': 2574.6800000000003, 'end': 2577.6, 'text': ' but I think to the extent rates have to go higher', 'tokens': [457, 286, 519, 281, 264, 8396, 6846, 362, 281, 352, 2946], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2570
# {'id': 671, 'seek': 256640, 'start': 2577.6, 'end': 2582.32, 'text': ' and stay higher for longer, it becomes harder to see the path.', 'tokens': [293, 1754, 2946, 337, 2854, 11, 309, 3643, 6081, 281, 536, 264, 3100, 13], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2575
# {'id': 672, 'seek': 256640, 'start': 2582.32, 'end': 2583.32, 'text': " It's narrowed.", 'tokens': [467, 311, 9432, 292, 13], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2580
# {'id': 673, 'seek': 256640, 'start': 2583.32, 'end': 2585.8, 'text': ' I would say the path is narrowed over the course of the last year,', 'tokens': [286, 576, 584, 264, 3100, 307, 9432, 292, 670, 264, 1164, 295, 264, 1036, 1064, 11], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2580
# {'id': 674, 'seek': 256640, 'start': 2585.8, 'end': 2586.64, 'text': ' really.', 'tokens': [534, 13], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2585
# {'id': 675, 'seek': 256640, 'start': 2587.88, 'end': 2589.36, 'text': ' Hard to say, hard to say.', 'tokens': [11817, 281, 584, 11, 1152, 281, 584, 13], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2585
# {'id': 676, 'seek': 256640, 'start': 2589.36, 'end': 2594.36, 'text': ' You know, again, I would say that the sort of array of data', 'tokens': [509, 458, 11, 797, 11, 286, 576, 584, 300, 264, 1333, 295, 10225, 295, 1412], 'temperature': 0.0, 'avg_logprob': -0.21552861638429785, 'compression_ratio': 1.6853448275862069, 'no_speech_prob': 0.0001534246257506311}
# 2585
# {'id': 677, 'seek': 259436, 'start': 2594.36, 'end': 2599.36, 'text': ' in the labor market is highly unusual, and to many economists,', 'tokens': [294, 264, 5938, 2142, 307, 5405, 10901, 11, 293, 281, 867, 32431, 11], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2590
# {'id': 678, 'seek': 259436, 'start': 2599.36, 'end': 2603.36, 'text': " there is a path to, there's an ordinarial,", 'tokens': [456, 307, 257, 3100, 281, 11, 456, 311, 364, 4792, 6470, 831, 11], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2595
# {'id': 679, 'seek': 259436, 'start': 2603.36, 'end': 2607.36, 'text': " there's a relationship to GP going down", 'tokens': [456, 311, 257, 2480, 281, 26039, 516, 760], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2600
# {'id': 680, 'seek': 259436, 'start': 2607.36, 'end': 2612.36, 'text': ' and vacancies declining, translating into unemployment,', 'tokens': [293, 2842, 32286, 34298, 11, 35030, 666, 17438, 11], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2605
# {'id': 681, 'seek': 259436, 'start': 2613.36, 'end': 2614.36, 'text': " or there's Oaken's law.", 'tokens': [420, 456, 311, 422, 9846, 311, 2101, 13], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2610
# {'id': 682, 'seek': 259436, 'start': 2614.36, 'end': 2617.36, 'text': ' So all those things are relationships that are in the data', 'tokens': [407, 439, 729, 721, 366, 6159, 300, 366, 294, 264, 1412], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2610
# {'id': 683, 'seek': 259436, 'start': 2617.36, 'end': 2618.36, 'text': " and they're very real.", 'tokens': [293, 436, 434, 588, 957, 13], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2615
# {'id': 684, 'seek': 259436, 'start': 2618.36, 'end': 2620.36, 'text': " There's a little bit different this time, though,", 'tokens': [821, 311, 257, 707, 857, 819, 341, 565, 11, 1673, 11], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2615
# {'id': 685, 'seek': 259436, 'start': 2620.36, 'end': 2623.36, 'text': ' because you have this tremendously high level of vacancies,', 'tokens': [570, 291, 362, 341, 27985, 1090, 1496, 295, 2842, 32286, 11], 'temperature': 0.0, 'avg_logprob': -0.3155770041725852, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.00018217743490822613}
# 2620
# {'id': 686, 'seek': 262336, 'start': 2623.36, 'end': 2626.36, 'text': ' we think on a very steep part of the beverage curve,', 'tokens': [321, 519, 322, 257, 588, 16841, 644, 295, 264, 35519, 7605, 11], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2620
# {'id': 687, 'seek': 262336, 'start': 2626.36, 'end': 2631.36, 'text': ' all I would say is that the job losses may turn out', 'tokens': [439, 286, 576, 584, 307, 300, 264, 1691, 15352, 815, 1261, 484], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2625
# {'id': 688, 'seek': 262336, 'start': 2631.36, 'end': 2635.36, 'text': ' to be less than would be indicated by those traditional measures', 'tokens': [281, 312, 1570, 813, 576, 312, 16176, 538, 729, 5164, 8000], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2630
# {'id': 689, 'seek': 262336, 'start': 2635.36, 'end': 2638.36, 'text': ' because job openings are so elevated', 'tokens': [570, 1691, 35941, 366, 370, 23457], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2635
# {'id': 690, 'seek': 262336, 'start': 2638.36, 'end': 2641.36, 'text': ' and because the labor market is so strong.', 'tokens': [293, 570, 264, 5938, 2142, 307, 370, 2068, 13], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2635
# {'id': 691, 'seek': 262336, 'start': 2641.36, 'end': 2644.36, 'text': " Again, that's gonna be something we discover empirically.", 'tokens': [3764, 11, 300, 311, 799, 312, 746, 321, 4411, 25790, 984, 13], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2640
# {'id': 692, 'seek': 262336, 'start': 2644.36, 'end': 2648.36, 'text': " I think no one knows whether there's gonna be a recession", 'tokens': [286, 519, 572, 472, 3255, 1968, 456, 311, 799, 312, 257, 24828], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2640
# {'id': 693, 'seek': 262336, 'start': 2648.36, 'end': 2652.36, 'text': ' or not, and if so, how bad that recession would be,', 'tokens': [420, 406, 11, 293, 498, 370, 11, 577, 1578, 300, 24828, 576, 312, 11], 'temperature': 0.0, 'avg_logprob': -0.08118500799502966, 'compression_ratio': 1.6746987951807228, 'no_speech_prob': 0.0002487102465238422}
# 2645
# {'id': 694, 'seek': 265236, 'start': 2652.36, 'end': 2657.36, 'text': ' and our job is to restore price stability', 'tokens': [293, 527, 1691, 307, 281, 15227, 3218, 11826], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2650
# {'id': 695, 'seek': 265236, 'start': 2657.36, 'end': 2659.36, 'text': ' so that we can have a strong labor market', 'tokens': [370, 300, 321, 393, 362, 257, 2068, 5938, 2142], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2655
# {'id': 696, 'seek': 265236, 'start': 2659.36, 'end': 2662.36, 'text': " that benefits all over time, and that's what we're gonna do.", 'tokens': [300, 5311, 439, 670, 565, 11, 293, 300, 311, 437, 321, 434, 799, 360, 13], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2655
# {'id': 697, 'seek': 265236, 'start': 2662.36, 'end': 2666.36, 'text': ' Just real quickly, why do you feel like the window is narrowed?', 'tokens': [1449, 957, 2661, 11, 983, 360, 291, 841, 411, 264, 4910, 307, 9432, 292, 30], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2660
# {'id': 698, 'seek': 265236, 'start': 2666.36, 'end': 2670.36, 'text': " Because we haven't seen inflation coming down.", 'tokens': [1436, 321, 2378, 380, 1612, 15860, 1348, 760, 13], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2665
# {'id': 699, 'seek': 265236, 'start': 2670.36, 'end': 2673.36, 'text': ' The implication of inflation not coming down,', 'tokens': [440, 37814, 295, 15860, 406, 1348, 760, 11], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2670
# {'id': 700, 'seek': 265236, 'start': 2673.36, 'end': 2676.36, 'text': ' and what we would expect by now to have seen', 'tokens': [293, 437, 321, 576, 2066, 538, 586, 281, 362, 1612], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2670
# {'id': 701, 'seek': 265236, 'start': 2676.36, 'end': 2681.36, 'text': ' is that really as a supply side, problems had resolved themselves.', 'tokens': [307, 300, 534, 382, 257, 5847, 1252, 11, 2740, 632, 20772, 2969, 13], 'temperature': 0.0, 'avg_logprob': -0.12270552317301432, 'compression_ratio': 1.619607843137255, 'no_speech_prob': 0.0005027619772590697}
# 2675
# {'id': 702, 'seek': 268136, 'start': 2681.36, 'end': 2685.36, 'text': ' We would have expected goods inflation to come down by now,', 'tokens': [492, 576, 362, 5176, 10179, 15860, 281, 808, 760, 538, 586, 11], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2680
# {'id': 703, 'seek': 268136, 'start': 2685.36, 'end': 2688.36, 'text': " long since by now, and it really hasn't,", 'tokens': [938, 1670, 538, 586, 11, 293, 309, 534, 6132, 380, 11], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2685
# {'id': 704, 'seek': 268136, 'start': 2688.36, 'end': 2690.36, 'text': " although it's actually it has come down,", 'tokens': [4878, 309, 311, 767, 309, 575, 808, 760, 11], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2685
# {'id': 705, 'seek': 268136, 'start': 2690.36, 'end': 2692.36, 'text': " but it's not to the extent we had hoped.", 'tokens': [457, 309, 311, 406, 281, 264, 8396, 321, 632, 19737, 13], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2690
# {'id': 706, 'seek': 268136, 'start': 2692.36, 'end': 2695.36, 'text': ' At the same time, now you see services inflation,', 'tokens': [1711, 264, 912, 565, 11, 586, 291, 536, 3328, 15860, 11], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2690
# {'id': 707, 'seek': 268136, 'start': 2695.36, 'end': 2697.36, 'text': ' core services inflation moving up,', 'tokens': [4965, 3328, 15860, 2684, 493, 11], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2695
# {'id': 708, 'seek': 268136, 'start': 2697.36, 'end': 2701.36, 'text': ' and I just think that the inflation picture', 'tokens': [293, 286, 445, 519, 300, 264, 15860, 3036], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2695
# {'id': 709, 'seek': 268136, 'start': 2701.36, 'end': 2703.36, 'text': ' has become more and more challenging', 'tokens': [575, 1813, 544, 293, 544, 7595], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2700
# {'id': 710, 'seek': 268136, 'start': 2703.36, 'end': 2705.36, 'text': ' over the course of this year without question.', 'tokens': [670, 264, 1164, 295, 341, 1064, 1553, 1168, 13], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2700
# {'id': 711, 'seek': 268136, 'start': 2705.36, 'end': 2709.36, 'text': ' That means that we have to have policy be more restrictive', 'tokens': [663, 1355, 300, 321, 362, 281, 362, 3897, 312, 544, 43220], 'temperature': 0.0, 'avg_logprob': -0.07232704655877475, 'compression_ratio': 1.752895752895753, 'no_speech_prob': 0.00016328596393577754}
# 2705
# {'id': 712, 'seek': 270936, 'start': 2709.36, 'end': 2712.36, 'text': ' and that narrows the path to a soft landing, I would say.', 'tokens': [293, 300, 6397, 1509, 264, 3100, 281, 257, 2787, 11202, 11, 286, 576, 584, 13], 'temperature': 0.0, 'avg_logprob': -0.10811532537142436, 'compression_ratio': 1.0, 'no_speech_prob': 4.8236106522381306e-05}
# 2705
# {'id': 713, 'seek': 271236, 'start': 2712.36, 'end': 2739.36, 'text': ' Thanks very much.', 'tokens': [50364, 2561, 588, 709, 13, 51714], 'temperature': 0.0, 'avg_logprob': -0.2021411316735404, 'compression_ratio': 0.68, 'no_speech_prob': 0.0006286752177402377}
# 2710

# %% [markdown]
# ## Combining Speech Data with Price Data
#
# Now that we have this speech and the associated timestamps, we can go further by merging these segments into a dataframe containing price data. Let's see how the speech maps to the price of the S&P 500. I have retrieved 5 second OHLCV data for SPY using Interactive Brokers. A copy of this data and the code used to retrieve it are located on the website. We can upload spy.csv to Colab and process it using pandas.

# %%
import pandas as pd

# %%
spy = pd.read_csv("spy.csv")

# %% [markdown]
# In the dataframe below, you can see the open, high, low, and close for each 5 second time period that occurred during the speech.

# %%
spy
# Out:
#                     date    open    high     low   close   volume  average  \
# 0    2022-11-02 14:31:15  387.13  387.17  386.75  386.83  82173.0  386.884
# 1    2022-11-02 14:31:20  386.80  387.00  386.80  386.91  38918.0  386.913
# 2    2022-11-02 14:31:25  386.94  386.96  386.55  386.64  48165.0  386.749
# 3    2022-11-02 14:31:30  386.64  386.95  386.59  386.86  30688.0  386.760
# 4    2022-11-02 14:31:35  386.91  386.92  386.81  386.87  22270.0  386.862
# ..                   ...     ...     ...     ...     ...      ...      ...
# 538  2022-11-02 15:16:05  380.30  380.48  380.30  380.39  40401.0  380.418
# 539  2022-11-02 15:16:10  380.37  380.49  380.24  380.45  40709.0  380.378
# 540  2022-11-02 15:16:15  380.45  380.48  380.38  380.39  12465.0  380.425
# 541  2022-11-02 15:16:20  380.38  380.38  380.28  380.36  24107.0  380.324
# 542  2022-11-02 15:16:25  380.35  380.36  380.28  380.34  12428.0  380.311
#
#      barCount
# 0         444
# 1         234
# 2         232
# 3         190
# 4         130
# ..        ...
# 538       265
# 539       221
# 540        69
# 541       139
# 542        91
#
# [543 rows x 8 columns]

# %% [markdown]
# Since we already have the segments of the speech and their start and end times in seconds, we can add a new column containing the text that was spoken during each 5 second bar.

# %%
for segment in output['segments']:
   second = int(segment['start'])
   second = second - (second % 5)
   spy.loc[second / 5, 'text'] = segment['text']

spy
# Out:
#                     date    open    high     low   close   volume  average  \
# 0    2022-11-02 14:31:15  387.13  387.17  386.75  386.83  82173.0  386.884
# 1    2022-11-02 14:31:20  386.80  387.00  386.80  386.91  38918.0  386.913
# 2    2022-11-02 14:31:25  386.94  386.96  386.55  386.64  48165.0  386.749
# 3    2022-11-02 14:31:30  386.64  386.95  386.59  386.86  30688.0  386.760
# 4    2022-11-02 14:31:35  386.91  386.92  386.81  386.87  22270.0  386.862
# ..                   ...     ...     ...     ...     ...      ...      ...
# 538  2022-11-02 15:16:05  380.30  380.48  380.30  380.39  40401.0  380.418
# 539  2022-11-02 15:16:10  380.37  380.49  380.24  380.45  40709.0  380.378
# 540  2022-11-02 15:16:15  380.45  380.48  380.38  380.39  12465.0  380.425
# 541  2022-11-02 15:16:20  380.38  380.38  380.28  380.36  24107.0  380.324
# 542  2022-11-02 15:16:25  380.35  380.36  380.28  380.34  12428.0  380.311
#
#      barCount                                               text
# 0         444   Good afternoon. My colleagues and I are stron...
# 1         234   We have both the tools that we need and the r...
# 2         232                                                NaN
# 3         190   Price stability is the responsibility of the ...
# 4         130   Without price stability, the economy does not...
# ..        ...                                                ...
# 538       265   At the same time, now you see services inflat...
# 539       221        and I just think that the inflation picture
# 540        69     over the course of this year without question.
# 541       139   and that narrows the path to a soft landing, ...
# 542        91                                  Thanks very much.
#
# [543 rows x 9 columns]

# %% [markdown]
# Let's also create a new column called *percent* that stores the percent the price moved during the 5 second period.

# %%
spy['percent'] = ((spy['close'] - spy['open']) / spy['open']) * 100

# %%
spy
# Out:
#                     date    open    high     low   close   volume  average  \
# 0    2022-11-02 14:31:15  387.13  387.17  386.75  386.83  82173.0  386.884
# 1    2022-11-02 14:31:20  386.80  387.00  386.80  386.91  38918.0  386.913
# 2    2022-11-02 14:31:25  386.94  386.96  386.55  386.64  48165.0  386.749
# 3    2022-11-02 14:31:30  386.64  386.95  386.59  386.86  30688.0  386.760
# 4    2022-11-02 14:31:35  386.91  386.92  386.81  386.87  22270.0  386.862
# ..                   ...     ...     ...     ...     ...      ...      ...
# 538  2022-11-02 15:16:05  380.30  380.48  380.30  380.39  40401.0  380.418
# 539  2022-11-02 15:16:10  380.37  380.49  380.24  380.45  40709.0  380.378
# 540  2022-11-02 15:16:15  380.45  380.48  380.38  380.39  12465.0  380.425
# 541  2022-11-02 15:16:20  380.38  380.38  380.28  380.36  24107.0  380.324
# 542  2022-11-02 15:16:25  380.35  380.36  380.28  380.34  12428.0  380.311
#
#      barCount                                               text   percent
# 0         444   Good afternoon. My colleagues and I are stron... -0.077493
# 1         234   We have both the tools that we need and the r...  0.028438
# 2         232                                                NaN -0.077531
# 3         190   Price stability is the responsibility of the ...  0.056900
# 4         130   Without price stability, the economy does not... -0.010338
# ..        ...                                                ...       ...
# 538       265   But it's not to the extent we had hoped at th...  0.023666
# 539       221                                                NaN  0.021032
# 540        69                                                NaN -0.015771
# 541       139                                                NaN -0.005258
# 542        91                                  Thanks very much. -0.002629
#
# [543 rows x 10 columns]

# %% [markdown]
# We can now filter our dataframe to show bars where the price moved more than a certain percentage. To see where price moved down substantially in a 5 second period, we can filter like so:

# %%
big_downmoves = spy[spy.percent < -0.2]

# %%
big_downmoves
# Out:
#                     date    open    high     low   close    volume  average  \
# 61   2022-11-02 14:36:20  387.74  387.84  386.42  386.45  214600.0  387.037
# 62   2022-11-02 14:36:25  386.40  386.44  385.36  385.52  289403.0  385.919
# 78   2022-11-02 14:37:45  383.70  383.70  382.90  382.93  152778.0  383.279
# 93   2022-11-02 14:39:00  383.67  383.69  382.82  382.83   64429.0  383.275
# 154  2022-11-02 14:44:05  385.86  385.87  385.07  385.08   73029.0  385.440
#
#      barCount                                               text   percent
# 61       1225                                                NaN -0.332697
# 62       1731   At some point, as I've said in the last two p... -0.227743
# 78        805   To conclude, we understand that our actions a... -0.200678
# 93        405    How will we know that we've reached that level? -0.218938
# 154       486                                                NaN -0.202146

# %% [markdown]
# Let's quickly visualize this and zoom in on 14:36 using mplfinance:

# %%
# !pip install mplfinance -q
import mplfinance as mpf

df = spy
df.index = pd.DatetimeIndex(df['date'])

mpf.plot(df['2022-11-02 14:36':'2022-11-02 14:39'],type='candle')

# %% [markdown]
# As we can see above, price moved significantly starting at 14:36 (row 61), so we can see the words spoken that led up to this:

# %%
spy[50:70]
# Out:
#                    date    open    high     low   close    volume  average  \
# 50  2022-11-02 14:35:25  386.91  387.24  386.88  387.19   24625.0  387.125
# 51  2022-11-02 14:35:30  387.21  387.81  387.20  387.77   97840.0  387.514
# 52  2022-11-02 14:35:35  387.73  387.93  387.63  387.65   95192.0  387.808
# 53  2022-11-02 14:35:40  387.64  387.76  387.52  387.55   30898.0  387.617
# 54  2022-11-02 14:35:45  387.56  388.19  387.56  388.16  148005.0  388.015
# 55  2022-11-02 14:35:50  388.15  388.63  388.14  388.22  154486.0  388.446
# 56  2022-11-02 14:35:55  388.25  388.46  388.02  388.42   51105.0  388.253
# 57  2022-11-02 14:36:00  388.46  388.47  388.02  388.23   61893.0  388.204
# 58  2022-11-02 14:36:05  388.24  388.34  387.58  387.69   93311.0  387.940
# 59  2022-11-02 14:36:10  387.69  388.12  387.69  388.10   65169.0  387.898
# 60  2022-11-02 14:36:15  388.11  388.28  387.66  387.74   68404.0  387.931
# 61  2022-11-02 14:36:20  387.74  387.84  386.42  386.45  214600.0  387.037
# 62  2022-11-02 14:36:25  386.40  386.44  385.36  385.52  289403.0  385.919
# 63  2022-11-02 14:36:30  385.56  385.97  385.23  385.96  182330.0  385.537
# 64  2022-11-02 14:36:35  385.92  385.94  385.27  385.27  155739.0  385.522
# 65  2022-11-02 14:36:40  385.29  385.37  384.83  384.89  174910.0  385.113
# 66  2022-11-02 14:36:45  384.95  384.97  384.42  384.63  134028.0  384.617
# 67  2022-11-02 14:36:50  384.65  384.84  384.22  384.33  144259.0  384.539
# 68  2022-11-02 14:36:55  384.30  384.30  383.90  383.99  138305.0  384.063
# 69  2022-11-02 14:37:00  383.94  384.66  383.87  384.66  158312.0  384.183
#
#     barCount                                               text   percent
# 50       181                                                NaN  0.072368
# 51       688                                                NaN  0.144624
# 52       475   With today's action, we've raised interest ra... -0.020633
# 53       162   We anticipate that ongoing increases in the t... -0.023217
# 54       823                                                NaN  0.154815
# 55       883                                                NaN  0.018034
# 56       320   Financial conditions have tightened significa...  0.043786
# 57       368                                                NaN -0.059208
# 58       520   It will take time, however, for the full effe... -0.141665
# 59       304   That's why we say in our statement that in de...  0.105755
# 60       465                                                NaN -0.095334
# 61      1225                                                NaN -0.332697
# 62      1731   At some point, as I've said in the last two p... -0.227743
# 63       896                                                NaN  0.103745
# 64       906                                                NaN -0.168429
# 65      1080   There is significant uncertainty around that ... -0.103818
# 66       836   Even so, we still have some ways to go, and i... -0.083128
# 67       694                                                NaN -0.083193
# 68       765   Our decisions will depend on the totality of ... -0.080666
# 69       856   We will continue to make our decisions meetin...  0.187529
