# %%
import pandas as pd
df = pd.read_csv('./Dataset.csv')
df.drop(['Ongata Rongai to Karen to Embakasi then back to Karen then Ongata Rongai'], axis="columns", inplace=True)
df.drop(df.index[[0]], inplace=True)
df.columns = df.iloc[0]
df.drop(df.index[[0]], inplace=True)
df.drop('Reg. No.', axis='columns', inplace=True)
df
# Out:
# 1          Lat         Lon Speed (km/h) Altitude  EngineState  Direction  \
# 2     -1.391675  36.776489            0    1711.3            0        SW
# 3     -1.391668  36.776497            2      1717         1800        NW
# 4     -1.391628  36.776451            3    1716.8         1800        NW
# 5     -1.391628  36.776451            2    1716.1         1800        SE
# 6     -1.391848   36.77634            6    1712.5         1800        SW
# ...         ...        ...          ...       ...          ...       ...
# 998   -1.390963  36.772316           32    1715.4         1800        SE
# 999      -1.391    36.7728           19    1714.4         1800        SE
# 1000  -1.391012  36.773426           11    1711.5         1800        NE
# 1001  -1.391048  36.774178           27    1712.5         1800        SE
# 1002  -1.391725  36.776432            0    1709.2            0        SE
#
# 1    Direction (Angle Changes)           Time      GPSTime  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_time = LabelEncoder()
le_direction = LabelEncoder()
df['Direction'] = le_direction.fit_transform(df['Direction'])
df['Time '] = le_direction.fit_transform(df['Time '])
df
# Out:
# 1          Lat         Lon Speed (km/h) Altitude  EngineState   Direction  \
# 2     -1.391675  36.776489            0    1711.3            0          6
# 3     -1.391668  36.776497            2      1717         1800          3
# 4     -1.391628  36.776451            3    1716.8         1800          3
# 5     -1.391628  36.776451            2    1716.1         1800          5
# 6     -1.391848   36.77634            6    1712.5         1800          6
# ...         ...        ...          ...       ...          ...        ...
# 998   -1.390963  36.772316           32    1715.4         1800          5
# 999      -1.391    36.7728           19    1714.4         1800          5
# 1000  -1.391012  36.773426           11    1711.5         1800          2
# 1001  -1.391048  36.774178           27    1712.5         1800          5
# 1002  -1.391725  36.776432            0    1709.2            0          5
#
# 1    Direction (Angle Changes)  Time      GPSTime GPS Signal Strength  \
# ...

# %%
df.columns

# %%
from sklearn.model_selection import train_test_split

df.fillna(0)
x = df.drop(labels='Direction (Angle Changes)', axis=1)
y = df['Direction (Angle Changes)']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)
X_train.tail()
# Out:
# 1         Lat         Lon Speed (km/h) Altitude  EngineState   Direction  \
# 722  -1.318438  36.733665          102    1816.4         1800          3
# 308  -1.342927  36.913757           60    1628.2         1800          3
# 29   -1.388543  36.769428           44      1706         1800          2
# 905  -1.354217  36.744617           52    1818.1         1800          2
# 697  -1.325085  36.755188          100    1796.1         1800          6
#
# 1    Time      GPSTime GPS Signal Strength Speed (m/s) Change in Speed (m/s)  \
# 722     59  1526461149                 0.8       28.33                  0.55
# 308    179  1526447563                 0.8       16.67                  3.06
# 29     146  1526445423                 0.8       12.22                 -1.39
# 905    110  1526480313                 0.8       14.44                  4.72
# 697     57  1526461036                 0.8       27.78                     0
#
# ...

# %%
from sklearn import tree

model = tree.DecisionTreeClassifier()
model.fit(X_train.fillna(0), y_train.fillna(0))

score = model.score(X_test.fillna(0), y_test.fillna(0))
print(f"Model Score is: {score}")
# Out:
# Model Score is: 0.2175226586102719

# %%
prediction = model.predict([X_test.iloc[302]])
time = X_test['Time '].iloc[302]
print(f"A random prediction of {time} for Direction (Angle Changes) is {prediction}")
# Out:
# A random prediction of 175 for Direction (Angle Changes) is ['130']
# /home/eren/Desktop/SnowCode/python/DataScience/Projects/MLCloud/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
